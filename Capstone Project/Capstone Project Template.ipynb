# %% [markdown]
# # Project Title
# ### Data Engineering Capstone Project
#
# #### Project Summary
#
# You are part of an Analytics team and tasked up to analyze the World Development Indicators(WDI) data and find which country is the most suitable to start up a Business.
#
# The project follows the follow steps:
# * Step 1: Scope the Project and Gather Data
# * Step 2: Explore and Assess the Data
# * Step 3: Define the Data Model
# * Step 4: Run ETL to Model the Data
# * Step 5: Complete Project Write Up

# %%
import os
from IPython.display import display, HTML
import pandas as pd

#Locating where pyspark is installed
import findspark
findspark.init()
import pyspark


#Settings for PySpark to work
driver_memory = '4g'
num_executors = 2
executor_memory = '1g'
#pyspark_submit_args = ' --driver-memory ' + driver_memory + ' --executor-memory ' + executor_memory + ' --num-executors ' + num_executors + ' pyspark-shell'
pyspark_submit_args = ' --driver-memory ' + driver_memory + ' pyspark-shell'

#Setting the required parameters to start up PySpark
os.environ["PYSPARK_SUBMIT_ARGS"] = pyspark_submit_args

#Import Modules Needed for PySpark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.functions import *
from pyspark.sql.types import IntegerType
from pyspark.sql.types import DecimalType

# %% [markdown]
# ### Step 1: Scope the Project and Gather Data
#
# #### Scope
# I will be using the available data about World Development Indicators data and will be creating an ETL pipeline that will extract the data from downloaded datasets and performing initial Exploratory Data Analysis and do necessary transformations and filtering. This filtered and transformed data will be later exported as csv files for further analysis.
#
# #### Describe and Gather Data
# For this purpose, I collected data from the following source:
#
# World Development Indicators(WDI- Data): https://datacatalog.worldbank.org/dataset/world-development-indicators
#
# Format: csv(comma-separated values)
#
# Granularity: National
#
# Number of Economies: 217
#
# Temporal Coverage: 1960 - 2020
#
# Release Date: June 11, 2010
#
# Last Updated: December 16, 2020

# %%
def showDF(df, limitRows =  20, truncate = True):
    if(truncate):
        pd.set_option('display.max_colwidth', 50)
    else:
        pd.set_option('display.max_colwidth', None)
    pd.set_option('display.max_rows', limitRows)
    display(df.limit(limitRows).toPandas())
    pd.reset_option('display.max_rows')

# %%
#Creating a spark session
spark = SparkSession.builder.appName("Data Engineering Nanodegree").getOrCreate()

# %% [markdown]
# ### Step 2: Explore and Assess the Data
# #### Explore the Data
# Identify data quality issues, like missing values, duplicate data, etc.
#
# #### Cleaning Steps
# Document steps necessary to clean the data

# %% [markdown]
# ##### Reading the Country wise data(WDICountry.csv)

# %%
#Read the file into a Spark Data Frame
wdicountry = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/home/jovyan/work/data/WDICountry.csv")

# %% [markdown]
# ##### Inspecting the schema we have just read

# %%
wdicountry.printSchema()
# Out:
# root
#  |-- Country Code: string (nullable = true)
#  |-- Short Name: string (nullable = true)
#  |-- Table Name: string (nullable = true)
#  |-- Long Name: string (nullable = true)
#  |-- 2-alpha code: string (nullable = true)
#  |-- Currency Unit: string (nullable = true)
#  |-- Special Notes: string (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Income Group: string (nullable = true)
#  |-- WB-2 code: string (nullable = true)
#  |-- National accounts base year: string (nullable = true)
#  |-- National accounts reference year: integer (nullable = true)
#  |-- SNA price valuation: string (nullable = true)
#  |-- Lending category: string (nullable = true)
#  |-- Other groups: string (nullable = true)
#  |-- System of National Accounts: string (nullable = true)
#  |-- Alternative conversion factor: string (nullable = true)
#  |-- PPP survey year: string (nullable = true)
#  |-- Balance of Payments Manual in use: string (nullable = true)
#  |-- External debt Reporting status: string (nullable = true)
#  |-- System of trade: string (nullable = true)
#  |-- Government Accounting concept: string (nullable = true)
#  |-- IMF data dissemination standard: string (nullable = true)
#  |-- Latest population census: string (nullable = true)
#  |-- Latest household survey: string (nullable = true)
#  |-- Source of most recent Income and expenditure data: string (nullable = true)
#  |-- Vital registration complete: string (nullable = true)
#  |-- Latest agricultural census: string (nullable = true)
#  |-- Latest industrial data: integer (nullable = true)
#  |-- Latest trade data: integer (nullable = true)
#  |-- Latest water withdrawal data: integer (nullable = true)

# %% [markdown]
# ##### Chekcing few sample data

# %%
showDF(wdicountry, truncate = False)
# Out:
#    Country Code            Short Name            Table Name  \
# 0           ABW                 Aruba                 Aruba
# 1           AFG           Afghanistan           Afghanistan
# 2           AGO                Angola                Angola
# 3           ALB               Albania               Albania
# 4           AND               Andorra               Andorra
# 5           ARB            Arab World            Arab World
# 6           ARE  United Arab Emirates  United Arab Emirates
# 7           ARG             Argentina             Argentina
# 8           ARM               Armenia               Armenia
# 9           ASM        American Samoa        American Samoa
# 10          ATG   Antigua and Barbuda   Antigua and Barbuda
# 11          AUS             Australia             Australia
# 12          AUT               Austria               Austria
# 13          AZE            Azerbaijan            Azerbaijan
# 14          BDI               Burundi               Burundi
# 15          BEL               Belgium               Belgium
# 16          BEN                 Benin                 Benin
# 17          BFA          Burkina Faso          Burkina Faso
# 18          BGD            Bangladesh            Bangladesh
# 19          BGR              Bulgaria              Bulgaria
#
#                           Long Name 2-alpha code           Currency Unit  \
# 0                             Aruba           AW           Aruban florin
# 1      Islamic State of Afghanistan           AF          Afghan afghani
# 2       People's Republic of Angola           AO          Angolan kwanza
# 3               Republic of Albania           AL            Albanian lek
# 4           Principality of Andorra           AD                    Euro
# 5                        Arab World           1A                    None
# 6              United Arab Emirates           AE           U.A.E. dirham
# 7                Argentine Republic           AR          Argentine peso
# 8               Republic of Armenia           AM           Armenian dram
# 9                    American Samoa           AS             U.S. dollar
# 10              Antigua and Barbuda           AG   East Caribbean dollar
# 11        Commonwealth of Australia           AU       Australian dollar
# 12              Republic of Austria           AT                    Euro
# 13           Republic of Azerbaijan           AZ         New Azeri manat
# 14              Republic of Burundi           BI           Burundi franc
# 15               Kingdom of Belgium           BE                    Euro
# 16                Republic of Benin           BJ  West African CFA franc
# 17                     Burkina Faso           BF  West African CFA franc
# 18  People's Republic of Bangladesh           BD        Bangladeshi taka
# 19             Republic of Bulgaria           BG           Bulgarian lev
#
#                                                                                                                                                                                                                                                                                                                                                            Special Notes  \
# 0                                                                                                                                                                                                                          SNA data for 2000-2011 are updated from official government statistics; 1994-1999 from UN databases. Base year has changed from 1995 to 2000.
# 1                                                 Fiscal year end: March 20; reporting period for national accounts data is calendar year, estimated to insure consistency between national accounts and fiscal data. National accounts data are sourced from the IMF and differ from the Central Statistics Organization numbers due to exclusion of the opium economy.
# 2                                                                                                                                                                                                                                                                                                                                                                   None
# 3                                                                                                                                                                                                                                                                                                                                                                   None
# 4                                                                                                                                                                                                                                                                                                              WB-3 code changed from ADO to AND to align with ISO code.
# 5                                                                                                                                                                                                                                                                                  Arab World aggregate. Arab World is composed of members of the League of Arab States.
# 6                                                                                                                                                                                                                                                                                                                                                                   None
# 7                                                                                      National Institute of Statistics and Census revised national accounts from 2004-2015. Argentina, which was temporarily unclassified in July 2016 pending release of revised national accounts statistics, is classified as upper middle income for FY17 as of September 29, 2016.
# 8                                                                                                                                                                                                                                                                                                                                                                   None
# 9                                                                                                                                                                                                                                                                                                                                                     New base Year 2009
# 10                                                                                                                                                                                                                                                                                                                                                                  None
# 11                                                                                                                                                                                                                 Fiscal year end: June 30; reporting period for national accounts data: FY. Value added current series updated by the Australian Bureau of Statistics;
# 12  A simple multiplier is used to convert the national currencies of EMU members to euros. The following irrevocable euro conversion rate was adopted by the EU Council on January 1, 1999: 1 euro = 13.7603 Austrian schilling. Please note that historical data before 1999 are not actual euros and are not comparable or suitable for aggregation across countries.
# 13                                                                                                                                                                                                                                                                                                                                                                  None
# 14                                                                                                                                                                                                                                                                                                                                                                  None
# 15       A simple multiplier is used to convert the national currencies of EMU members to euros. The following irrevocable euro conversion rate was adopted by the EU Council on January 1, 1999: 1 euro = 40.3399 Belgian franc. Please note that historical data before 1999 are not actual euros and are not comparable or suitable for aggregation across countries.
# 16                                                                                                                                                                                                                                                                                                                                                                  None
# 17                                                                                                                                                                                                                                                                                                                                                                  None
# 18                                                                                                                                                                                                                                                                                            Fiscal year end: June 30; reporting period for national accounts data: FY.
# 19                                                                                                                                                                                                                                                                                                                                                                  None
#
#                         Region         Income Group WB-2 code  ...  \
# 0    Latin America & Caribbean          High income        AW  ...
# 1                   South Asia           Low income        AF  ...
# 2           Sub-Saharan Africa  Lower middle income        AO  ...
# 3        Europe & Central Asia  Upper middle income        AL  ...
# 4        Europe & Central Asia          High income        AD  ...
# 5                         None                 None        1A  ...
# 6   Middle East & North Africa          High income        AE  ...
# 7                         None                 None      None  ...
# 8        Europe & Central Asia  Lower middle income        AM  ...
# 9          East Asia & Pacific  Upper middle income        AS  ...
# 10   Latin America & Caribbean          High income        AG  ...
# 11         East Asia & Pacific          High income        AU  ...
# 12       Europe & Central Asia          High income        AT  ...
# 13       Europe & Central Asia  Upper middle income        AZ  ...
# 14          Sub-Saharan Africa           Low income        BI  ...
# 15       Europe & Central Asia          High income        BE  ...
# 16          Sub-Saharan Africa           Low income        BJ  ...
# 17          Sub-Saharan Africa           Low income        BF  ...
# 18                  South Asia  Lower middle income        BD  ...
# 19       Europe & Central Asia  Upper middle income        BG  ...
#
#       Government Accounting concept  \
# 0                              None
# 1   Consolidated central government
# 2      Budgetary central government
# 3   Consolidated central government
# 4                              None
# 5                              None
# 6   Consolidated central government
# 7                              None
# 8   Consolidated central government
# 9                              None
# 10     Budgetary central government
# 11  Consolidated central government
# 12  Consolidated central government
# 13  Consolidated central government
# 14     Budgetary central government
# 15  Consolidated central government
# 16     Budgetary central government
# 17     Budgetary central government
# 18     Budgetary central government
# 19  Consolidated central government
#
#                         IMF data dissemination standard  \
# 0   Enhanced General Data Dissemination System (e-GDDS)
# 1   Enhanced General Data Dissemination System (e-GDDS)
# 2   Enhanced General Data Dissemination System (e-GDDS)
# 3   Enhanced General Data Dissemination System (e-GDDS)
# 4                                                  None
# 5                                                  None
# 6   Enhanced General Data Dissemination System (e-GDDS)
# 7                                                  None
# 8            Special Data Dissemination Standard (SDDS)
# 9                                                  None
# 10  Enhanced General Data Dissemination System (e-GDDS)
# 11           Special Data Dissemination Standard (SDDS)
# 12     Special Data Dissemination Standard Plus (SDDS+)
# 13  Enhanced General Data Dissemination System (e-GDDS)
# 14  Enhanced General Data Dissemination System (e-GDDS)
# 15           Special Data Dissemination Standard (SDDS)
# 16  Enhanced General Data Dissemination System (e-GDDS)
# 17  Enhanced General Data Dissemination System (e-GDDS)
# 18  Enhanced General Data Dissemination System (e-GDDS)
# 19     Special Data Dissemination Standard Plus (SDDS+)
#
#                                                                                                              Latest population census  \
# 0                                                                                                                                2010
# 1                                                                                                                                1979
# 2                                                                                                                                2014
# 3                                                                                                                                2011
# 4                                                                       2011. Population data compiled from administrative registers.
# 5                                                                                                                                None
# 6                                                                                                                                2010
# 7                                                                                                                                None
# 8                                                                                                                                2011
# 9                                                                                                                                2010
# 10                                                                                                                               2011
# 11                                                                                                                               2016
# 12                                                                      2011. Population data compiled from administrative registers.
# 13                                                                                                                               2009
# 14                                                                                                                               2008
# 15  2011. Population data compiled from administrative registers in combination with other sources of data, such as a sample surveys.
# 16                                                                                                                               2013
# 17                                                                                                                               2006
# 18                                                                                                                               2011
# 19                                                                                                                               2011
#
#                                                      Latest household survey  \
# 0                                                                       None
# 1                                        Demographic and Health Survey, 2015
# 2                                     Demographic and Health Survey, 2015/16
# 3                                     Demographic and Health Survey, 2008/09
# 4                                                                       None
# 5                                                                       None
# 6                                                  World Health Survey, 2003
# 7                                                                       None
# 8                                     Demographic and Health Survey, 2015/16
# 9                                                                       None
# 10                                                                      None
# 11                                                                      None
# 12                                                                      None
# 13                                       Demographic and Health Survey, 2006
# 14                                       Demographic and Health Survey, 2016
# 15                                                                      None
# 16                                   Multiple Indicator Cluster Survey, 2014
# 17  Living Standards Measurement Study, 2014; Malaria Indicator Survey, 2014
# 18                                       Demographic and Health Survey, 2014
# 19                                  Living Standards Measurement Study, 2007
#
#            Source of most recent Income and expenditure data  \
# 0                                                       None
# 1                    Integrated household survey (IHS), 2011
# 2                 Integrated household survey (IHS), 2008/09
# 3     Living Standards Measurement Study Survey (LSMS), 2012
# 4                                                       None
# 5                                                       None
# 6                                                       None
# 7                                                       None
# 8                    Integrated household survey (IHS), 2015
# 9                                                       None
# 10                                                      None
# 11            Expenditure survey/budget survey (ES/BS), 2010
# 12                                  Income survey (IS), 2014
# 13    Living Standards Measurement Study Survey (LSMS), 2012
# 14  Core Welfare Indicator Questionnaire Survey (CWIQ), 2014
# 15                                  Income survey (IS), 2014
# 16  Core Welfare Indicator Questionnaire Survey (CWIQ), 2015
# 17  Core Welfare Indicator Questionnaire Survey (CWIQ), 2014
# 18                   Integrated household survey (IHS), 2016
# 19            Expenditure survey/budget survey (ES/BS), 2014
#
#    Vital registration complete Latest agricultural census  \
# 0                          Yes                       None
# 1                         None                       None
# 2                         None                       None
# 3                          Yes                       2012
# 4                          Yes                       None
# 5                         None                       None
# 6                         None                       2012
# 7                         None                       None
# 8                          Yes                       2014
# 9                          Yes                       2008
# 10                         Yes                       2007
# 11                         Yes                       2011
# 12                         Yes                       2010
# 13                         Yes                       2015
# 14                        None                       None
# 15                         Yes                       2010
# 16                        None                       None
# 17                        None                    2006-10
# 18                        None                       2008
# 19                         Yes                       2010
#
#    Latest industrial data Latest trade data Latest water withdrawal data
# 0                     NaN            2016.0                          NaN
# 1                     NaN            2016.0                       2000.0
# 2                     NaN            2016.0                       2005.0
# 3                  2013.0            2016.0                       2006.0
# 4                     NaN               NaN                          NaN
# 5                     NaN            2016.0                          NaN
# 6                  1985.0            2016.0                       2005.0
# 7                     NaN               NaN                          NaN
# 8                     NaN            2016.0                       2012.0
# 9                     NaN            2016.0                          NaN
# 10                    NaN            2016.0                       2012.0
# 11                 2013.0            2016.0                       2013.0
# 12                 2014.0            2016.0                       2010.0
# 13                 2013.0            2016.0                       2012.0
# 14                 2012.0            2016.0                       2000.0
# 15                 2014.0            2016.0                       2009.0
# 16                 1981.0            2016.0                       2001.0
# 17                 1983.0            2016.0                       2005.0
# 18                 2011.0            2016.0                       2008.0
# 19                 2014.0            2016.0                       2013.0
#
# [20 rows x 31 columns]

# %% [markdown]
# ##### Analysing few basic stas on the data we have read

# %%
wdicountry.count()
# Out:
# 263

# %% [markdown]
# ##### Examining Country Data Dimensions

# %% [markdown]
# ##### How many different regions the countries belong to?

# %%
showDF(wdicountry.select('Region').distinct(), truncate = False)
# Out:
#                        Region
# 0                  South Asia
# 1                        None
# 2          Sub-Saharan Africa
# 3       Europe & Central Asia
# 4               North America
# 5         East Asia & Pacific
# 6  Middle East & North Africa
# 7   Latin America & Caribbean

# %% [markdown]
# ##### How many different income groups do we have across countries?

# %%
showDF(wdicountry.select('Income Group').distinct(), truncate = False)
# Out:
#           Income Group
# 0  Lower middle income
# 1                 None
# 2          High income
# 3  Upper middle income
# 4           Low income

# %% [markdown]
# ##### Reading Series data(WDISeries.csv)

# %%
wdiseries = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/home/jovyan/work/data/WDISeries.csv")

# %%
wdiseries.printSchema()
# Out:
# root
#  |-- Series Code: string (nullable = true)
#  |-- Topic: string (nullable = true)
#  |-- Indicator Name: string (nullable = true)
#  |-- Short definition: string (nullable = true)
#  |-- Long definition: string (nullable = true)
#  |-- Unit of measure: string (nullable = true)
#  |-- Periodicity: string (nullable = true)
#  |-- Base Period: string (nullable = true)
#  |-- Other notes: string (nullable = true)
#  |-- Aggregation method: string (nullable = true)
#  |-- Limitations and exceptions: string (nullable = true)
#  |-- Notes from original source: string (nullable = true)
#  |-- General comments: string (nullable = true)
#  |-- Source: string (nullable = true)
#  |-- Statistical concept and methodology: string (nullable = true)
#  |-- Development relevance: string (nullable = true)
#  |-- Related source links: string (nullable = true)
#  |-- Other web links: string (nullable = true)
#  |-- Related indicators: string (nullable = true)
#  |-- License Type: string (nullable = true)
#  |-- _c20: string (nullable = true)

# %%
showDF(wdiseries)
# Out:
#           Series Code                                 Topic  \
# 0      AG.AGR.TRAC.NO  Environment: Agricultural production
# 1   AG.CON.FERT.PT.ZS  Environment: Agricultural production
# 2      AG.CON.FERT.ZS  Environment: Agricultural production
# 3      AG.LND.AGRI.K2                 Environment: Land use
# 4      AG.LND.AGRI.ZS                 Environment: Land use
# 5      AG.LND.ARBL.HA                 Environment: Land use
# 6   AG.LND.ARBL.HA.PC                 Environment: Land use
# 7      AG.LND.ARBL.ZS                 Environment: Land use
# 8      AG.LND.CREL.HA  Environment: Agricultural production
# 9      AG.LND.CROP.ZS                 Environment: Land use
# 10  AG.LND.EL5M.RU.K2                 Environment: Land use
# 11  AG.LND.EL5M.RU.ZS                 Environment: Land use
# 12  AG.LND.EL5M.UR.K2                 Environment: Land use
# 13  AG.LND.EL5M.UR.ZS                 Environment: Land use
# 14     AG.LND.EL5M.ZS                 Environment: Land use
# 15     AG.LND.FRST.K2                 Environment: Land use
# 16     AG.LND.FRST.ZS                 Environment: Land use
# 17  AG.LND.IRIG.AG.ZS                 Environment: Land use
# 18     AG.LND.PRCP.MM                 Environment: Land use
# 19     AG.LND.TOTL.K2                 Environment: Land use
#
#                                        Indicator Name Short definition  \
# 0                    Agricultural machinery, tractors             None
# 1   Fertilizer consumption (% of fertilizer produc...             None
# 2   Fertilizer consumption (kilograms per hectare ...             None
# 3                          Agricultural land (sq. km)             None
# 4                  Agricultural land (% of land area)             None
# 5                              Arable land (hectares)             None
# 6                   Arable land (hectares per person)             None
# 7                        Arable land (% of land area)             None
# 8             Land under cereal production (hectares)             None
# 9                 Permanent cropland (% of land area)             None
# 10  Rural land area where elevation is below 5 met...             None
# 11  Rural land area where elevation is below 5 met...             None
# 12  Urban land area where elevation is below 5 met...             None
# 13  Urban land area where elevation is below 5 met...             None
# 14  Land area where elevation is below 5 meters (%...             None
# 15                               Forest area (sq. km)             None
# 16                       Forest area (% of land area)             None
# 17  Agricultural irrigated land (% of total agricu...             None
# 18       Average precipitation in depth (mm per year)             None
# 19                                 Land area (sq. km)             None
#
#                                       Long definition Unit of measure  \
# 0   Agricultural machinery refers to the number of...            None
# 1   Fertilizer consumption measures the quantity o...            None
# 2   Fertilizer consumption measures the quantity o...            None
# 3   Agricultural land refers to the share of land ...            None
# 4   Agricultural land refers to the share of land ...            None
# 5   Arable land (in hectares) includes land define...            None
# 6   Arable land (hectares per person) includes lan...            None
# 7   Arable land includes land defined by the FAO a...            None
# 8   Land under cereal production refers to harvest...            None
# 9   Permanent cropland is land cultivated with cro...            None
# 10  Rural land area below 5m is the total rural la...            None
# 11  Rural land area below 5m is the percentage of ...            None
# 12  Urban land area below 5m is the total urban la...            None
# 13  Urban land area below 5m is the percentage of ...            None
# 14  Land area below 5m is the percentage of total ...            None
# 15  Forest area is land under natural or planted s...            None
# 16  Forest area is land under natural or planted s...            None
# 17  Agricultural irrigated land refers to agricult...            None
# 18  Average precipitation is the long-term average...            None
# 19  Land area is a country's total area, excluding...            None
#
#    Periodicity Base Period Other notes Aggregation method  ...  \
# 0       Annual        None        None                Sum  ...
# 1       Annual        None        None   Weighted average  ...
# 2       Annual        None        None   Weighted average  ...
# 3       Annual        None        None                Sum  ...
# 4       Annual        None        None   Weighted average  ...
# 5       Annual        None        None               None  ...
# 6       Annual        None        None   Weighted Average  ...
# 7       Annual        None        None   Weighted average  ...
# 8       Annual        None        None                Sum  ...
# 9       Annual        None        None   Weighted average  ...
# 10      Annual        None        None                Sum  ...
# 11      Annual        None        None   Weighted Average  ...
# 12      Annual        None        None                Sum  ...
# 13      Annual        None        None   Weighted Average  ...
# 14      Annual        None        None   Weighted Average  ...
# 15      Annual        None        None                Sum  ...
# 16      Annual        None        None   Weighted average  ...
# 17      Annual        None        None   Weighted average  ...
# 18      Annual        None        None               None  ...
# 19      Annual        None        None                Sum  ...
#
#    Notes from original source General comments  \
# 0                        None             None
# 1                        None             None
# 2                        None             None
# 3                        None             None
# 4                        None             None
# 5                        None             None
# 6                        None             None
# 7                        None             None
# 8                        None             None
# 9                        None             None
# 10                       None             None
# 11                       None             None
# 12                       None             None
# 13                       None             None
# 14                       None             None
# 15                       None             None
# 16                       None             None
# 17                       None             None
# 18                       None             None
# 19                       None             None
#
#                                                Source  \
# 0   Food and Agriculture Organization, electronic ...
# 1   Food and Agriculture Organization, electronic ...
# 2   Food and Agriculture Organization, electronic ...
# 3   Food and Agriculture Organization, electronic ...
# 4   Food and Agriculture Organization, electronic ...
# 5   Food and Agriculture Organization, electronic ...
# 6   Food and Agriculture Organization, electronic ...
# 7   Food and Agriculture Organization, electronic ...
# 8   Food and Agriculture Organization, electronic ...
# 9   Food and Agriculture Organization, electronic ...
# 10  Center for International Earth Science Informa...
# 11  Center for International Earth Science Informa...
# 12  Center for International Earth Science Informa...
# 13  Center for International Earth Science Informa...
# 14  Center for International Earth Science Informa...
# 15  Food and Agriculture Organization, electronic ...
# 16  Food and Agriculture Organization, electronic ...
# 17  Food and Agriculture Organization, electronic ...
# 18  Food and Agriculture Organization, electronic ...
# 19  Food and Agriculture Organization, electronic ...
#
#                   Statistical concept and methodology  \
# 0   A tractor provides the power and traction to m...
# 1   Fertilizer consumption measures the quantity o...
# 2   Fertilizer consumption measures the quantity o...
# 3   Agricultural land constitutes only a part of a...
# 4   Agriculture is still a major sector in many ec...
# 5   Temporary fallow land refers to land left fall...
# 6   Temporary fallow land refers to land left fall...
# 7   Temporary fallow land refers to land left fall...
# 8   Cereals production includes wheat, rice, maize...
# 9   The data on Permanent cropland and land area a...
# 10  Elevation data used to generate the low elevat...
# 11  Elevation data used to generate the low elevat...
# 12  Elevation data used to generate the low elevat...
# 13  Elevation data used to generate the low elevat...
# 14  Elevation data used to generate the low elevat...
# 15  Forest is determined both by the presence of t...
# 16  Forest is determined both by the presence of t...
# 17  Irrigated agricultural area refers to area equ...
# 18                                               None
# 19  Total land area does not include inland water ...
#
#                                 Development relevance Related source links  \
# 0   Agricultural land covers more than one-third o...                 None
# 1   Factors such as the green revolution, has led ...                 None
# 2   Factors such as the green revolution, has led ...                 None
# 3   Agricultural land covers more than one-third o...                 None
# 4   Agricultural land covers more than one-third o...                 None
# 5   Agricultural land covers more than one-third o...                 None
# 6   Agricultural land covers about one-third of th...                 None
# 7   Agricultural land covers more than one-third o...                 None
# 8   The cultivation of cereals varies widely in di...                 None
# 9   Agricultural land covers more than one-third o...                 None
# 10                                               None                 None
# 11  Scientists use the terms climate change and gl...                 None
# 12  Scientists use the terms climate change and gl...                 None
# 13  Scientists use the terms climate change and gl...                 None
# 14  Scientists use the terms climate change and gl...                 None
# 15  As threats to biodiversity mount, the internat...                 None
# 16  As threats to biodiversity mount, the internat...                 None
# 17  Worldwide, irrigated agriculture accounts for ...                 None
# 18  The agriculture sector is the most water-inten...                 None
# 19  Land area is particularly important for unders...                 None
#
#    Other web links Related indicators License Type  _c20
# 0             None               None    CC BY-4.0  None
# 1             None               None    CC BY-4.0  None
# 2             None               None    CC BY-4.0  None
# 3             None               None    CC BY-4.0  None
# 4             None               None    CC BY-4.0  None
# 5             None               None    CC BY-4.0  None
# 6             None               None    CC BY-4.0  None
# 7             None               None    CC BY-4.0  None
# 8             None               None    CC BY-4.0  None
# 9             None               None    CC BY-4.0  None
# 10            None               None    CC BY-4.0  None
# 11            None               None    CC BY-4.0  None
# 12            None               None    CC BY-4.0  None
# 13            None               None    CC BY-4.0  None
# 14            None               None    CC BY-4.0  None
# 15            None               None    CC BY-4.0  None
# 16            None               None    CC BY-4.0  None
# 17            None               None    CC BY-4.0  None
# 18            None               None    CC BY-4.0  None
# 19            None               None    CC BY-4.0  None
#
# [20 rows x 21 columns]

# %%
wdiseries.count()
# Out:
# 1593

# %% [markdown]
# ##### Examining Series Data Dimensions

# %% [markdown]
# ##### What are the different periodicities or aggregation methods we might expect to see in the data ?

# %%
showDF(wdiseries.select('Periodicity').distinct(), truncate = False)
# Out:
#                                                                                                    Periodicity
# 0                                                                                                       Annual
# 1                                                                                                         None
# 2                                                                            Quarterly (represented as Annual)
# 3  International Civil Aviation Organization, Civil Aviation Statistics of the World and ICAO staff estimates.

# %%
showDF(wdiseries.select('Aggregation Method').distinct(), truncate = False)
# Out:
#                     Aggregation Method
# 0                                 None
# 1                     Weighted average
# 2                       Simple average
# 3                     Gap-filled total
# 4                               Median
# 5                   Unweighted average
# 6  Linear mixed-effect model estimates
# 7                     Weighted Average
# 8                                  Sum

# %% [markdown]
# ##### Reading the World Development Indicators data(WDIData.csv)

# %%
# Read the data
wdiindicators = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/home/jovyan/work/data/WDIData.csv")

# %%
# Inspect the schema
wdiindicators.printSchema()
# Out:
# root
#  |-- Country Name: string (nullable = true)
#  |-- Country Code: string (nullable = true)
#  |-- Indicator Name: string (nullable = true)
#  |-- Indicator Code: string (nullable = true)
#  |-- 1960: double (nullable = true)
#  |-- 1961: double (nullable = true)
#  |-- 1962: double (nullable = true)
#  |-- 1963: double (nullable = true)
#  |-- 1964: double (nullable = true)
#  |-- 1965: double (nullable = true)
#  |-- 1966: double (nullable = true)
#  |-- 1967: double (nullable = true)
#  |-- 1968: double (nullable = true)
#  |-- 1969: double (nullable = true)
#  |-- 1970: double (nullable = true)
#  |-- 1971: double (nullable = true)
#  |-- 1972: double (nullable = true)
#  |-- 1973: double (nullable = true)
#  |-- 1974: double (nullable = true)
#  |-- 1975: double (nullable = true)
#  |-- 1976: double (nullable = true)
#  |-- 1977: double (nullable = true)
#  |-- 1978: double (nullable = true)
#  |-- 1979: double (nullable = true)
#  |-- 1980: double (nullable = true)
#  |-- 1981: double (nullable = true)
#  |-- 1982: double (nullable = true)
#  |-- 1983: double (nullable = true)
#  |-- 1984: double (nullable = true)
#  |-- 1985: double (nullable = true)
#  |-- 1986: double (nullable = true)
#  |-- 1987: double (nullable = true)
#  |-- 1988: double (nullable = true)
#  |-- 1989: double (nullable = true)
#  |-- 1990: double (nullable = true)
#  |-- 1991: double (nullable = true)
#  |-- 1992: double (nullable = true)
#  |-- 1993: double (nullable = true)
#  |-- 1994: double (nullable = true)
#  |-- 1995: double (nullable = true)
#  |-- 1996: double (nullable = true)
#  |-- 1997: double (nullable = true)
#  |-- 1998: double (nullable = true)
#  |-- 1999: double (nullable = true)
#  |-- 2000: double (nullable = true)
#  |-- 2001: double (nullable = true)
#  |-- 2002: double (nullable = true)
#  |-- 2003: double (nullable = true)
#  |-- 2004: double (nullable = true)
#  |-- 2005: double (nullable = true)
#  |-- 2006: double (nullable = true)
#  |-- 2007: double (nullable = true)
#  |-- 2008: double (nullable = true)
#  |-- 2009: double (nullable = true)
#  |-- 2010: double (nullable = true)
#  |-- 2011: double (nullable = true)
#  |-- 2012: double (nullable = true)
#  |-- 2013: double (nullable = true)
#  |-- 2014: double (nullable = true)
#  |-- 2015: double (nullable = true)
#  |-- 2016: double (nullable = true)
#  |-- 2017: double (nullable = true)
#  |-- 2018: double (nullable = true)
#  |-- 2019: double (nullable = true)
#  |-- 2020: double (nullable = true)
#  |-- _c65: string (nullable = true)

# %%
# Look at sample records
showDF(wdiindicators)
# Out:
#    Country Name Country Code  \
# 0    Arab World          ARB
# 1    Arab World          ARB
# 2    Arab World          ARB
# 3    Arab World          ARB
# 4    Arab World          ARB
# 5    Arab World          ARB
# 6    Arab World          ARB
# 7    Arab World          ARB
# 8    Arab World          ARB
# 9    Arab World          ARB
# 10   Arab World          ARB
# 11   Arab World          ARB
# 12   Arab World          ARB
# 13   Arab World          ARB
# 14   Arab World          ARB
# 15   Arab World          ARB
# 16   Arab World          ARB
# 17   Arab World          ARB
# 18   Arab World          ARB
# 19   Arab World          ARB
#
#                                        Indicator Name  \
# 0   Access to clean fuels and technologies for coo...
# 1             Access to electricity (% of population)
# 2   Access to electricity, rural (% of rural popul...
# 3   Access to electricity, urban (% of urban popul...
# 4   Account ownership at a financial institution o...
# 5   Account ownership at a financial institution o...
# 6   Account ownership at a financial institution o...
# 7   Account ownership at a financial institution o...
# 8   Account ownership at a financial institution o...
# 9   Account ownership at a financial institution o...
# 10  Account ownership at a financial institution o...
# 11  Account ownership at a financial institution o...
# 12  Account ownership at a financial institution o...
# 13  Adequacy of social insurance programs (% of to...
# 14  Adequacy of social protection and labor progra...
# 15  Adequacy of social safety net programs (% of t...
# 16  Adequacy of unemployment benefits and ALMP (% ...
# 17  Adjusted net enrollment rate, primary (% of pr...
# 18  Adjusted net enrollment rate, primary, female ...
# 19  Adjusted net enrollment rate, primary, male (%...
#
#               Indicator Code  1960  1961  1962  1963  1964  1965  ...  \
# 0             EG.CFT.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1             EG.ELC.ACCS.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 2          EG.ELC.ACCS.RU.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3          EG.ELC.ACCS.UR.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4             FX.OWN.TOTL.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 5          FX.OWN.TOTL.FE.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 6          FX.OWN.TOTL.MA.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 7          FX.OWN.TOTL.OL.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 8          FX.OWN.TOTL.40.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 9          FX.OWN.TOTL.PL.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 10         FX.OWN.TOTL.60.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 11         FX.OWN.TOTL.SO.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 12         FX.OWN.TOTL.YG.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 13  per_si_allsi.adq_pop_tot   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 14     per_allsp.adq_pop_tot   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 15  per_sa_allsa.adq_pop_tot   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 16  per_lm_alllm.adq_pop_tot   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 17               SE.PRM.TENR   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 18            SE.PRM.TENR.FE   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 19            SE.PRM.TENR.MA   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#          2012       2013       2014       2015       2016       2017  \
# 0   83.120303  83.533457  83.897596  84.171599  84.510171        NaN
# 1   87.512260  88.129881  87.275323  88.720097  89.308602  90.283638
# 2   77.251714  78.165706  75.512153  78.211000  79.065508  81.102134
# 3   96.435957  96.772853  96.466705  96.936319  97.290083  97.467915
# 4         NaN        NaN  30.277130        NaN        NaN  37.165211
# 5         NaN        NaN  22.079350        NaN        NaN  25.635403
# 6         NaN        NaN  37.790764        NaN        NaN  48.328518
# 7         NaN        NaN  34.216583        NaN        NaN  42.542046
# 8         NaN        NaN  22.779890        NaN        NaN  27.724781
# 9         NaN        NaN  21.278042        NaN        NaN  26.458111
# 10        NaN        NaN  35.237480        NaN        NaN  43.446953
# 11        NaN        NaN  38.900612        NaN        NaN  48.666977
# 12        NaN        NaN  21.256142        NaN        NaN  20.954800
# 13        NaN        NaN        NaN        NaN        NaN        NaN
# 14        NaN        NaN        NaN        NaN        NaN        NaN
# 15        NaN        NaN        NaN        NaN        NaN        NaN
# 16        NaN        NaN        NaN        NaN        NaN        NaN
# 17  85.207140  84.218320  84.254300  84.035230  84.532580  85.143750
# 18  84.118780  83.218390  83.344940  83.189960  83.820280  83.994780
# 19  86.300590  85.225830  85.183590  84.895170  85.254640  86.288360
#
#          2018  2019  2020  _c65
# 0         NaN   NaN   NaN  None
# 1   89.286856   NaN   NaN  None
# 2   79.248100   NaN   NaN  None
# 3   97.063959   NaN   NaN  None
# 4         NaN   NaN   NaN  None
# 5         NaN   NaN   NaN  None
# 6         NaN   NaN   NaN  None
# 7         NaN   NaN   NaN  None
# 8         NaN   NaN   NaN  None
# 9         NaN   NaN   NaN  None
# 10        NaN   NaN   NaN  None
# 11        NaN   NaN   NaN  None
# 12        NaN   NaN   NaN  None
# 13        NaN   NaN   NaN  None
# 14        NaN   NaN   NaN  None
# 15        NaN   NaN   NaN  None
# 16        NaN   NaN   NaN  None
# 17  85.384220   NaN   NaN  None
# 18  84.252780   NaN   NaN  None
# 19  86.506010   NaN   NaN  None
#
# [20 rows x 66 columns]

# %%
# Get some basic stats
wdiindicators.count()
# Out:
# 380160

# %%
from IPython.display import Image

# %% [markdown]
# ### Step 3: Define the Data Model
# #### 3.1 Conceptual Data Model
# Map out the conceptual data model and explain why you chose that model
#
# ##### Since the goal is data exploration, the data is normalized for query execution. Each table is given a primary key and data extracted as needed. I have built the conceptual data model based on the star schema because a star schema database has a small number of tables and clear join paths, queries run faster than they do against an OLTP system. Small single-table queries, usually of dimension tables, are almost instantaneous. Large join queries that involve multiple tables take only seconds or minutes to run.
#
# ![alt text](datamodel.jpg "Title")
#
# #### 3.2 Mapping Out Data Pipelines
# ##### Please find the below data transformation logics which will map out the data model mentioned above

# %% [markdown]
# #### Data Transformation Logic

# %% [markdown]
# #### Transform Country Data
# - Select the columns that we will need for our data model
# - Rename columns for data ingestion

# %%
wdicountryDim = wdicountry \
    .select("2-alpha code", "Country Code", "Short Name", "Long Name", "Region", "Income Group") \
    .withColumnRenamed("2-alpha code", "country_iso_code") \
    .withColumnRenamed("Country Code", "wb_country_code") \
    .withColumnRenamed("Short Name", "country_name") \
    .withColumnRenamed("Long Name", "country_long_name") \
    .withColumnRenamed("Region", "region") \
    .withColumnRenamed("Income Group", "income_group")
    
showDF(wdicountryDim)
# Out:
#    country_iso_code wb_country_code          country_name  \
# 0                AW             ABW                 Aruba
# 1                AF             AFG           Afghanistan
# 2                AO             AGO                Angola
# 3                AL             ALB               Albania
# 4                AD             AND               Andorra
# 5                1A             ARB            Arab World
# 6                AE             ARE  United Arab Emirates
# 7                AR             ARG             Argentina
# 8                AM             ARM               Armenia
# 9                AS             ASM        American Samoa
# 10               AG             ATG   Antigua and Barbuda
# 11               AU             AUS             Australia
# 12               AT             AUT               Austria
# 13               AZ             AZE            Azerbaijan
# 14               BI             BDI               Burundi
# 15               BE             BEL               Belgium
# 16               BJ             BEN                 Benin
# 17               BF             BFA          Burkina Faso
# 18               BD             BGD            Bangladesh
# 19               BG             BGR              Bulgaria
#
#                   country_long_name                      region  \
# 0                             Aruba   Latin America & Caribbean
# 1      Islamic State of Afghanistan                  South Asia
# 2       People's Republic of Angola          Sub-Saharan Africa
# 3               Republic of Albania       Europe & Central Asia
# 4           Principality of Andorra       Europe & Central Asia
# 5                        Arab World                        None
# 6              United Arab Emirates  Middle East & North Africa
# 7                Argentine Republic                        None
# 8               Republic of Armenia       Europe & Central Asia
# 9                    American Samoa         East Asia & Pacific
# 10              Antigua and Barbuda   Latin America & Caribbean
# 11        Commonwealth of Australia         East Asia & Pacific
# 12              Republic of Austria       Europe & Central Asia
# 13           Republic of Azerbaijan       Europe & Central Asia
# 14              Republic of Burundi          Sub-Saharan Africa
# 15               Kingdom of Belgium       Europe & Central Asia
# 16                Republic of Benin          Sub-Saharan Africa
# 17                     Burkina Faso          Sub-Saharan Africa
# 18  People's Republic of Bangladesh                  South Asia
# 19             Republic of Bulgaria       Europe & Central Asia
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7                  None
# 8   Lower middle income
# 9   Upper middle income
# 10          High income
# 11          High income
# 12          High income
# 13  Upper middle income
# 14           Low income
# 15          High income
# 16           Low income
# 17           Low income
# 18  Lower middle income
# 19  Upper middle income

# %%
#Lets you create a view that you can use in SQL queries
wdicountryDim.createOrReplaceTempView("wdicountryvw")

# %%
transformQuery = """
select 
    country_iso_code
    , wb_country_code
    , country_name as name
    , country_long_name as long_name
    , region
    , income_group
from 
    wdicountryvw
"""

showDF(spark.sql(transformQuery))
# Out:
#    country_iso_code wb_country_code                  name  \
# 0                AW             ABW                 Aruba
# 1                AF             AFG           Afghanistan
# 2                AO             AGO                Angola
# 3                AL             ALB               Albania
# 4                AD             AND               Andorra
# 5                1A             ARB            Arab World
# 6                AE             ARE  United Arab Emirates
# 7                AR             ARG             Argentina
# 8                AM             ARM               Armenia
# 9                AS             ASM        American Samoa
# 10               AG             ATG   Antigua and Barbuda
# 11               AU             AUS             Australia
# 12               AT             AUT               Austria
# 13               AZ             AZE            Azerbaijan
# 14               BI             BDI               Burundi
# 15               BE             BEL               Belgium
# 16               BJ             BEN                 Benin
# 17               BF             BFA          Burkina Faso
# 18               BD             BGD            Bangladesh
# 19               BG             BGR              Bulgaria
#
#                           long_name                      region  \
# 0                             Aruba   Latin America & Caribbean
# 1      Islamic State of Afghanistan                  South Asia
# 2       People's Republic of Angola          Sub-Saharan Africa
# 3               Republic of Albania       Europe & Central Asia
# 4           Principality of Andorra       Europe & Central Asia
# 5                        Arab World                        None
# 6              United Arab Emirates  Middle East & North Africa
# 7                Argentine Republic                        None
# 8               Republic of Armenia       Europe & Central Asia
# 9                    American Samoa         East Asia & Pacific
# 10              Antigua and Barbuda   Latin America & Caribbean
# 11        Commonwealth of Australia         East Asia & Pacific
# 12              Republic of Austria       Europe & Central Asia
# 13           Republic of Azerbaijan       Europe & Central Asia
# 14              Republic of Burundi          Sub-Saharan Africa
# 15               Kingdom of Belgium       Europe & Central Asia
# 16                Republic of Benin          Sub-Saharan Africa
# 17                     Burkina Faso          Sub-Saharan Africa
# 18  People's Republic of Bangladesh                  South Asia
# 19             Republic of Bulgaria       Europe & Central Asia
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7                  None
# 8   Lower middle income
# 9   Upper middle income
# 10          High income
# 11          High income
# 12          High income
# 13  Upper middle income
# 14           Low income
# 15          High income
# 16           Low income
# 17           Low income
# 18  Lower middle income
# 19  Upper middle income

# %%
transformQuery = """
select 
    count(*)
from 
    wdicountry
"""

showDF(spark.sql(transformQuery))
# Out:
#    count(1)
# 0       263

# %% [markdown]
# #### Transform the Series Dataset
# - Filter only for series that have Annual periodicity
# - Get the following columns and rename the selected columns to prepare further processing

# %%
wdiseriesDim = wdiseries \
    .select("Series Code", "Indicator Name", "Short Definition", "Periodicity", "Aggregation Method") \
    .withColumnRenamed("Series Code", "indicator_code") \
    .withColumnRenamed("Indicator Name", "indicator_name") \
    .withColumnRenamed("Periodicity", "periodicity") \
    .withColumnRenamed("Aggregation Method", "aggregation_method") \
    .filter(col("periodicity") == "Annual") 
    
showDF(wdiseriesDim)

wdiseriesDim.count()
# Out:
#        indicator_code                                     indicator_name  \
# 0      AG.AGR.TRAC.NO                   Agricultural machinery, tractors
# 1   AG.CON.FERT.PT.ZS  Fertilizer consumption (% of fertilizer produc...
# 2      AG.CON.FERT.ZS  Fertilizer consumption (kilograms per hectare ...
# 3      AG.LND.AGRI.K2                         Agricultural land (sq. km)
# 4      AG.LND.AGRI.ZS                 Agricultural land (% of land area)
# 5      AG.LND.ARBL.HA                             Arable land (hectares)
# 6   AG.LND.ARBL.HA.PC                  Arable land (hectares per person)
# 7      AG.LND.ARBL.ZS                       Arable land (% of land area)
# 8      AG.LND.CREL.HA            Land under cereal production (hectares)
# 9      AG.LND.CROP.ZS                Permanent cropland (% of land area)
# 10  AG.LND.EL5M.RU.K2  Rural land area where elevation is below 5 met...
# 11  AG.LND.EL5M.RU.ZS  Rural land area where elevation is below 5 met...
# 12  AG.LND.EL5M.UR.K2  Urban land area where elevation is below 5 met...
# 13  AG.LND.EL5M.UR.ZS  Urban land area where elevation is below 5 met...
# 14     AG.LND.EL5M.ZS  Land area where elevation is below 5 meters (%...
# 15     AG.LND.FRST.K2                               Forest area (sq. km)
# 16     AG.LND.FRST.ZS                       Forest area (% of land area)
# 17  AG.LND.IRIG.AG.ZS  Agricultural irrigated land (% of total agricu...
# 18     AG.LND.PRCP.MM       Average precipitation in depth (mm per year)
# 19     AG.LND.TOTL.K2                                 Land area (sq. km)
#
#    Short Definition periodicity aggregation_method
# 0              None      Annual                Sum
# 1              None      Annual   Weighted average
# 2              None      Annual   Weighted average
# 3              None      Annual                Sum
# 4              None      Annual   Weighted average
# 5              None      Annual               None
# 6              None      Annual   Weighted Average
# 7              None      Annual   Weighted average
# 8              None      Annual                Sum
# 9              None      Annual   Weighted average
# 10             None      Annual                Sum
# 11             None      Annual   Weighted Average
# 12             None      Annual                Sum
# 13             None      Annual   Weighted Average
# 14             None      Annual   Weighted Average
# 15             None      Annual                Sum
# 16             None      Annual   Weighted average
# 17             None      Annual   Weighted average
# 18             None      Annual               None
# 19             None      Annual                Sum
# 1587

# %% [markdown]
# ##### Our dataset has multiple types of metrics. The only ones that we care about are simple aggregates.

# %%
simpleAggInd = wdiseriesDim \
    .filter("lower(aggregation_method) = 'sum'") \
    .select("indicator_code", "indicator_name") \
    .orderBy("indicator_code")

showDF(simpleAggInd, limitRows = 500, truncate = False)
# Out:
#            indicator_code  \
# 0          AG.AGR.TRAC.NO
# 1          AG.LND.AGRI.K2
# 2          AG.LND.CREL.HA
# 3       AG.LND.EL5M.RU.K2
# 4       AG.LND.EL5M.UR.K2
# 5          AG.LND.FRST.K2
# 6          AG.LND.TOTL.K2
# 7       AG.LND.TOTL.RU.K2
# 8       AG.LND.TOTL.UR.K2
# 9          AG.PRD.CREL.MT
# 10         AG.SRF.TOTL.K2
# 11         BM.GSR.FCTY.CD
# 12         BM.GSR.ROYL.CD
# 13      BM.KLT.DINV.CD.WD
# 14         BM.TRF.PRVT.CD
# 15      BM.TRF.PWKR.CD.DT
# 16      BX.GRT.EXTA.CD.WD
# 17      BX.GRT.TECH.CD.WD
# 18         BX.GSR.CCIS.CD
# 19         BX.GSR.FCTY.CD
# 20         BX.GSR.ROYL.CD
# 21      BX.KLT.DINV.CD.WD
# 22      BX.KLT.DREM.CD.DT
# 23      BX.PEF.TOTL.CD.WD
# 24         BX.TRF.CURR.CD
# 25         BX.TRF.PWKR.CD
# 26      BX.TRF.PWKR.CD.DT
# 27         CM.MKT.LCAP.CD
# 28         CM.MKT.LDOM.NO
# 29         CM.MKT.TRAD.CD
# 30         DC.DAC.AUSL.CD
# 31         DC.DAC.AUTL.CD
# 32         DC.DAC.BELL.CD
# 33         DC.DAC.CANL.CD
# 34         DC.DAC.CECL.CD
# 35         DC.DAC.CHEL.CD
# 36         DC.DAC.CZEL.CD
# 37         DC.DAC.DEUL.CD
# 38         DC.DAC.DNKL.CD
# 39         DC.DAC.ESPL.CD
# 40         DC.DAC.FINL.CD
# 41         DC.DAC.FRAL.CD
# 42         DC.DAC.GBRL.CD
# 43         DC.DAC.GRCL.CD
# 44         DC.DAC.IRLL.CD
# 45         DC.DAC.ISLL.CD
# 46         DC.DAC.ITAL.CD
# 47         DC.DAC.JPNL.CD
# 48         DC.DAC.KORL.CD
# 49         DC.DAC.LUXL.CD
# 50         DC.DAC.NLDL.CD
# 51         DC.DAC.NORL.CD
# 52         DC.DAC.NZLL.CD
# 53         DC.DAC.POLL.CD
# 54         DC.DAC.PRTL.CD
# 55         DC.DAC.SVKL.CD
# 56         DC.DAC.SVNL.CD
# 57         DC.DAC.SWEL.CD
# 58         DC.DAC.TOTL.CD
# 59         DC.DAC.USAL.CD
# 60         DT.AMT.BLAT.CD
# 61         DT.AMT.BLTC.CD
# 62         DT.AMT.DIMF.CD
# 63         DT.AMT.DLTF.CD
# 64         DT.AMT.DLXF.CD
# 65         DT.AMT.DPNG.CD
# 66         DT.AMT.DPPG.CD
# 67         DT.AMT.MIBR.CD
# 68         DT.AMT.MIDA.CD
# 69         DT.AMT.MLAT.CD
# 70         DT.AMT.MLTC.CD
# 71         DT.AMT.OFFT.CD
# 72         DT.AMT.PBND.CD
# 73         DT.AMT.PCBK.CD
# 74         DT.AMT.PNGB.CD
# 75         DT.AMT.PNGC.CD
# 76         DT.AMT.PROP.CD
# 77         DT.AMT.PRVT.CD
# 78         DT.AXA.DPPG.CD
# 79         DT.AXA.OFFT.CD
# 80         DT.AXA.PRVT.CD
# 81         DT.AXF.DPPG.CD
# 82         DT.AXR.DPPG.CD
# 83         DT.AXR.OFFT.CD
# 84         DT.AXR.PRVT.CD
# 85         DT.COM.DPPG.CD
# 86         DT.COM.MIBR.CD
# 87         DT.COM.MIDA.CD
# 88         DT.COM.OFFT.CD
# 89         DT.COM.PRVT.CD
# 90         DT.DFR.DPPG.CD
# 91         DT.DIS.BLAT.CD
# 92         DT.DIS.BLTC.CD
# 93         DT.DIS.DIMF.CD
# 94         DT.DIS.DLTF.CD
# 95         DT.DIS.DLXF.CD
# 96         DT.DIS.DPNG.CD
# 97         DT.DIS.DPPG.CD
# 98         DT.DIS.IDAG.CD
# 99         DT.DIS.MIBR.CD
# 100        DT.DIS.MIDA.CD
# 101        DT.DIS.MLAT.CD
# 102        DT.DIS.MLTC.CD
# 103        DT.DIS.OFFT.CD
# 104        DT.DIS.PBND.CD
# 105        DT.DIS.PCBK.CD
# 106        DT.DIS.PNGB.CD
# 107        DT.DIS.PNGC.CD
# 108        DT.DIS.PROP.CD
# 109        DT.DIS.PRVT.CD
# 110        DT.DOD.ALLC.CD
# 111        DT.DOD.BLAT.CD
# 112        DT.DOD.BLTC.CD
# 113        DT.DOD.DECT.CD
# 114     DT.DOD.DECT.CD.CG
# 115        DT.DOD.DIMF.CD
# 116        DT.DOD.DLXF.CD
# 117        DT.DOD.DPNG.CD
# 118        DT.DOD.DPPG.CD
# 119        DT.DOD.DSTC.CD
# 120        DT.DOD.MDRI.CD
# 121        DT.DOD.MIBR.CD
# 122        DT.DOD.MIDA.CD
# 123        DT.DOD.MLAT.CD
# 124        DT.DOD.MLTC.CD
# 125        DT.DOD.MWBG.CD
# 126        DT.DOD.OFFT.CD
# 127        DT.DOD.PBND.CD
# 128        DT.DOD.PCBK.CD
# 129        DT.DOD.PNGB.CD
# 130        DT.DOD.PNGC.CD
# 131        DT.DOD.PROP.CD
# 132        DT.DOD.PRVS.CD
# 133        DT.DOD.PRVT.CD
# 134        DT.DOD.PUBS.CD
# 135        DT.DOD.PVLX.CD
# 136        DT.DOD.RSDL.CD
# 137        DT.DOD.VTOT.CD
# 138        DT.DSB.DPPG.CD
# 139        DT.DSF.DPPG.CD
# 140        DT.DXR.DPPG.CD
# 141        DT.INT.BLAT.CD
# 142        DT.INT.BLTC.CD
# 143        DT.INT.DECT.CD
# 144        DT.INT.DIMF.CD
# 145        DT.INT.DLXF.CD
# 146        DT.INT.DPNG.CD
# 147        DT.INT.DPPG.CD
# 148        DT.INT.DSTC.CD
# 149        DT.INT.MIBR.CD
# 150        DT.INT.MIDA.CD
# 151        DT.INT.MLAT.CD
# 152        DT.INT.MLTC.CD
# 153        DT.INT.OFFT.CD
# 154        DT.INT.PBND.CD
# 155        DT.INT.PCBK.CD
# 156        DT.INT.PNGB.CD
# 157        DT.INT.PNGC.CD
# 158        DT.INT.PROP.CD
# 159        DT.INT.PRVT.CD
# 160        DT.IXA.DPPG.CD
# 161     DT.IXA.DPPG.CD.CG
# 162        DT.IXA.OFFT.CD
# 163        DT.IXA.PRVT.CD
# 164        DT.IXF.DPPG.CD
# 165        DT.IXR.DPPG.CD
# 166        DT.IXR.OFFT.CD
# 167        DT.IXR.PRVT.CD
# 168        DT.NFL.BLAT.CD
# 169        DT.NFL.BLTC.CD
# 170        DT.NFL.BOND.CD
# 171        DT.NFL.DECT.CD
# 172        DT.NFL.DLXF.CD
# 173        DT.NFL.DPNG.CD
# 174        DT.NFL.DPPG.CD
# 175        DT.NFL.DSTC.CD
# 176        DT.NFL.FAOG.CD
# 177        DT.NFL.IAEA.CD
# 178        DT.NFL.IFAD.CD
# 179        DT.NFL.ILOG.CD
# 180        DT.NFL.IMFC.CD
# 181        DT.NFL.IMFN.CD
# 182        DT.NFL.MIBR.CD
# 183        DT.NFL.MIDA.CD
# 184        DT.NFL.MLAT.CD
# 185        DT.NFL.MLTC.CD
# 186        DT.NFL.MOTH.CD
# 187        DT.NFL.NEBR.CD
# 188        DT.NFL.NIFC.CD
# 189        DT.NFL.OFFT.CD
# 190        DT.NFL.PBND.CD
# 191        DT.NFL.PCBK.CD
# 192        DT.NFL.PCBO.CD
# 193        DT.NFL.PNGB.CD
# 194        DT.NFL.PNGC.CD
# 195        DT.NFL.PROP.CD
# 196        DT.NFL.PRVT.CD
# 197        DT.NFL.RDBC.CD
# 198        DT.NFL.RDBN.CD
# 199        DT.NFL.UNAI.CD
# 200        DT.NFL.UNCF.CD
# 201        DT.NFL.UNCR.CD
# 202        DT.NFL.UNDP.CD
# 203        DT.NFL.UNEC.CD
# 204        DT.NFL.UNFP.CD
# 205        DT.NFL.UNPB.CD
# 206        DT.NFL.UNRW.CD
# 207        DT.NFL.UNTA.CD
# 208        DT.NFL.WFPG.CD
# 209        DT.NFL.WHOL.CD
# 210        DT.NTR.BLAT.CD
# 211        DT.NTR.BLTC.CD
# 212        DT.NTR.DECT.CD
# 213        DT.NTR.DLXF.CD
# 214        DT.NTR.DPNG.CD
# 215        DT.NTR.DPPG.CD
# 216        DT.NTR.MIBR.CD
# 217        DT.NTR.MIDA.CD
# 218        DT.NTR.MLAT.CD
# 219        DT.NTR.MLTC.CD
# 220        DT.NTR.OFFT.CD
# 221        DT.NTR.PBND.CD
# 222        DT.NTR.PCBK.CD
# 223        DT.NTR.PNGB.CD
# 224        DT.NTR.PNGC.CD
# 225        DT.NTR.PROP.CD
# 226        DT.NTR.PRVT.CD
# 227        DT.ODA.ALLD.CD
# 228        DT.ODA.ALLD.KD
# 229        DT.ODA.OATL.CD
# 230        DT.ODA.OATL.KD
# 231        DT.ODA.ODAT.CD
# 232        DT.ODA.ODAT.KD
# 233        DT.TDS.BLAT.CD
# 234        DT.TDS.BLTC.CD
# 235        DT.TDS.DECT.CD
# 236        DT.TDS.DIMF.CD
# 237        DT.TDS.DLXF.CD
# 238        DT.TDS.DPNG.CD
# 239        DT.TDS.DPPG.CD
# 240        DT.TDS.MIBR.CD
# 241        DT.TDS.MIDA.CD
# 242        DT.TDS.MLAT.CD
# 243        DT.TDS.MLTC.CD
# 244        DT.TDS.OFFT.CD
# 245        DT.TDS.PBND.CD
# 246        DT.TDS.PCBK.CD
# 247        DT.TDS.PNGB.CD
# 248        DT.TDS.PNGC.CD
# 249        DT.TDS.PROP.CD
# 250        DT.TDS.PRVT.CD
# 251        DT.TXR.DPPG.CD
# 252        DT.UND.DPPG.CD
# 253        DT.UND.OFFT.CD
# 254        DT.UND.PRVT.CD
# 255        EG.ELC.RNWX.KH
# 256     EN.ATM.GHGO.KT.CE
# 257     EN.ATM.GHGT.KT.CE
# 258  EN.ATM.METH.AG.KT.CE
# 259  EN.ATM.METH.EG.KT.CE
# 260     EN.ATM.METH.KT.CE
# 261  EN.ATM.NOXE.AG.KT.CE
# 262  EN.ATM.NOXE.EG.KT.CE
# 263     EN.ATM.NOXE.KT.CE
# 264        EN.BIR.THRD.NO
# 265        EN.FSH.THRD.NO
# 266        EN.HPT.THRD.NO
# 267        EN.MAM.THRD.NO
# 268        ER.FSH.AQUA.MT
# 269        ER.FSH.CAPT.MT
# 270        ER.FSH.PROD.MT
# 271        ER.H2O.FWTL.K3
# 272        ER.H2O.INTR.K3
# 273        IE.PPI.ENGY.CD
# 274        IE.PPI.ICTI.CD
# 275        IE.PPI.TELE.CD
# 276        IE.PPI.TRAN.CD
# 277        IE.PPI.WATR.CD
# 278        IE.PPN.ENGY.CD
# 279        IE.PPN.ICTI.CD
# 280        IE.PPN.TELE.CD
# 281        IE.PPN.TRAN.CD
# 282        IE.PPN.WATR.CD
# 283           IP.IDS.NRCT
# 284           IP.IDS.RSCT
# 285           IP.PAT.NRES
# 286           IP.PAT.RESD
# 287           IP.TMK.NRCT
# 288           IP.TMK.NRES
# 289           IP.TMK.RESD
# 290           IP.TMK.RSCT
# 291           IP.TMK.TOTL
# 292           IS.AIR.DPRT
# 293     IS.AIR.GOOD.MT.K1
# 294           IS.AIR.PSGR
# 295        IS.RRS.TOTL.KM
# 296        IS.SHP.GOOD.TU
# 297           IT.CEL.SETS
# 298           IT.MLT.MAIN
# 299           IT.NET.BBND
# 300           IT.NET.SECR
# 301        MS.MIL.MPRT.KD
# 302        MS.MIL.TOTL.P1
# 303        MS.MIL.XPRT.KD
# 304           SE.PRM.ENRL
# 305           SE.PRM.TCHR
# 306           SE.PRM.UNER
# 307        SE.PRM.UNER.FE
# 308        SE.PRM.UNER.MA
# 309           SE.SEC.ENRL
# 310        SE.SEC.ENRL.GC
# 311        SE.SEC.ENRL.VO
# 312           SE.SEC.TCHR
# 313        SE.SEC.TCHR.FE
# 314           SH.DTH.0514
# 315           SH.DTH.IMRT
# 316           SH.DTH.MORT
# 317           SH.DTH.NMRT
# 318           SH.MMR.DTHS
# 319        SH.UHC.NOP1.TO
# 320        SH.UHC.NOP2.TO
# 321     SH.UHC.OOPC.10.TO
# 322     SH.UHC.OOPC.25.TO
# 323        SL.TLF.TOTL.IN
# 324           SM.POP.NETM
# 325           SM.POP.REFG
# 326        SM.POP.REFG.OR
# 327           SM.POP.TOTL
# 328     SP.POP.0014.FE.IN
# 329     SP.POP.0014.MA.IN
# 330        SP.POP.0014.TO
# 331     SP.POP.1564.FE.IN
# 332     SP.POP.1564.MA.IN
# 333        SP.POP.1564.TO
# 334     SP.POP.65UP.FE.IN
# 335     SP.POP.65UP.MA.IN
# 336        SP.POP.65UP.TO
# 337           SP.POP.TOTL
# 338     SP.POP.TOTL.FE.IN
# 339     SP.POP.TOTL.MA.IN
# 340           SP.RUR.TOTL
# 341           SP.URB.TOTL
# 342     TM.VAL.MRCH.WL.CD
# 343     TX.VAL.MRCH.WL.CD
# 344        TX.VAL.TECH.CD
# 345           VC.BTL.DETH
# 346           VC.IDP.NWCV
# 347           VC.IDP.NWDS
# 348           VC.IDP.TOCV
# 349        VC.PKP.TOTL.UN
#
#                                                                                                           indicator_name
# 0                                                                                       Agricultural machinery, tractors
# 1                                                                                             Agricultural land (sq. km)
# 2                                                                                Land under cereal production (hectares)
# 3                                                             Rural land area where elevation is below 5 meters (sq. km)
# 4                                                             Urban land area where elevation is below 5 meters (sq. km)
# 5                                                                                                   Forest area (sq. km)
# 6                                                                                                     Land area (sq. km)
# 7                                                                                               Rural land area (sq. km)
# 8                                                                                               Urban land area (sq. km)
# 9                                                                                        Cereal production (metric tons)
# 10                                                                                                 Surface area (sq. km)
# 11                                                                            Primary income payments (BoP, current US$)
# 12                                             Charges for the use of intellectual property, payments (BoP, current US$)
# 13                                                            Foreign direct investment, net outflows (BoP, current US$)
# 14                                                          Secondary income, other sectors, payments (BoP, current US$)
# 15                                                                              Personal remittances, paid (current US$)
# 16                                                            Grants, excluding technical cooperation (BoP, current US$)
# 17                                                                       Technical cooperation grants (BoP, current US$)
# 18                                                                                ICT service exports (BoP, current US$)
# 19                                                                            Primary income receipts (BoP, current US$)
# 20                                             Charges for the use of intellectual property, receipts (BoP, current US$)
# 21                                                             Foreign direct investment, net inflows (BoP, current US$)
# 22                                                                                   Primary income on FDI (current US$)
# 23                                                                      Portfolio equity, net inflows (BoP, current US$)
# 24                                                                          Secondary income receipts (BoP, current US$)
# 25                                                                       Personal transfers, receipts (BoP, current US$)
# 26                                                                          Personal remittances, received (current US$)
# 27                                                      Market capitalization of listed domestic companies (current US$)
# 28                                                                                      Listed domestic companies, total
# 29                                                                              Stocks traded, total value (current US$)
# 30                                                      Net bilateral aid flows from DAC donors, Australia (current US$)
# 31                                                        Net bilateral aid flows from DAC donors, Austria (current US$)
# 32                                                        Net bilateral aid flows from DAC donors, Belgium (current US$)
# 33                                                         Net bilateral aid flows from DAC donors, Canada (current US$)
# 34                                    Net bilateral aid flows from DAC donors, European Union institutions (current US$)
# 35                                                    Net bilateral aid flows from DAC donors, Switzerland (current US$)
# 36                                                 Net bilateral aid flows from DAC donors, Czech Republic (current US$)
# 37                                                        Net bilateral aid flows from DAC donors, Germany (current US$)
# 38                                                        Net bilateral aid flows from DAC donors, Denmark (current US$)
# 39                                                          Net bilateral aid flows from DAC donors, Spain (current US$)
# 40                                                        Net bilateral aid flows from DAC donors, Finland (current US$)
# 41                                                         Net bilateral aid flows from DAC donors, France (current US$)
# 42                                                 Net bilateral aid flows from DAC donors, United Kingdom (current US$)
# 43                                                         Net bilateral aid flows from DAC donors, Greece (current US$)
# 44                                                        Net bilateral aid flows from DAC donors, Ireland (current US$)
# 45                                                        Net bilateral aid flows from DAC donors, Iceland (current US$)
# 46                                                          Net bilateral aid flows from DAC donors, Italy (current US$)
# 47                                                          Net bilateral aid flows from DAC donors, Japan (current US$)
# 48                                                    Net bilateral aid flows from DAC donors, Korea, Rep. (current US$)
# 49                                                     Net bilateral aid flows from DAC donors, Luxembourg (current US$)
# 50                                                    Net bilateral aid flows from DAC donors, Netherlands (current US$)
# 51                                                         Net bilateral aid flows from DAC donors, Norway (current US$)
# 52                                                    Net bilateral aid flows from DAC donors, New Zealand (current US$)
# 53                                                         Net bilateral aid flows from DAC donors, Poland (current US$)
# 54                                                       Net bilateral aid flows from DAC donors, Portugal (current US$)
# 55                                                Net bilateral aid flows from DAC donors, Slovak Republic (current US$)
# 56                                                       Net bilateral aid flows from DAC donors, Slovenia (current US$)
# 57                                                         Net bilateral aid flows from DAC donors, Sweden (current US$)
# 58                                                          Net bilateral aid flows from DAC donors, Total (current US$)
# 59                                                  Net bilateral aid flows from DAC donors, United States (current US$)
# 60                                                                                     PPG, bilateral (AMT, current US$)
# 61                                                                        PPG, bilateral concessional (AMT, current US$)
# 62                                                                                    IMF repurchases (AMT, current US$)
# 63                                             Principal repayments on external debt, long-term + IMF (AMT, current US$)
# 64                                                   Principal repayments on external debt, long-term (AMT, current US$)
# 65                                 Principal repayments on external debt, private nonguaranteed (PNG) (AMT, current US$)
# 66                        Principal repayments on external debt, public and publicly guaranteed (PPG) (AMT, current US$)
# 67                                                                                          PPG, IBRD (AMT, current US$)
# 68                                                                                           PPG, IDA (AMT, current US$)
# 69                                                                                  PPG, multilateral (AMT, current US$)
# 70                                                                     PPG, multilateral concessional (AMT, current US$)
# 71                                                                            PPG, official creditors (AMT, current US$)
# 72                                                                                         PPG, bonds (AMT, current US$)
# 73                                                                              PPG, commercial banks (AMT, current US$)
# 74                                                                                         PNG, bonds (AMT, current US$)
# 75                                                          PNG, commercial banks and other creditors (AMT, current US$)
# 76                                                                       PPG, other private creditors (AMT, current US$)
# 77                                                                             PPG, private creditors (AMT, current US$)
# 78                                                       Principal arrears, public and publicly guaranteed (current US$)
# 79                                                                   Principal arrears, official creditors (current US$)
# 80                                                                    Principal arrears, private creditors (current US$)
# 81                                                                                      Principal forgiven (current US$)
# 82                                                                                   Principal rescheduled (current US$)
# 83                                                                         Principal rescheduled, official (current US$)
# 84                                                                          Principal rescheduled, private (current US$)
# 85                                                        Commitments, public and publicly guaranteed (COM, current US$)
# 86                                                                                  Commitments, IBRD (COM, current US$)
# 87                                                                                   Commitments, IDA (COM, current US$)
# 88                                                                    Commitments, official creditors (COM, current US$)
# 89                                                                     Commitments, private creditors (COM, current US$)
# 90                                                                           Debt forgiveness or reduction (current US$)
# 91                                                                                     PPG, bilateral (DIS, current US$)
# 92                                                                        PPG, bilateral concessional (DIS, current US$)
# 93                                                                                      IMF purchases (DIS, current US$)
# 94                                                    Disbursements on external debt, long-term + IMF (DIS, current US$)
# 95                                                          Disbursements on external debt, long-term (DIS, current US$)
# 96                                        Disbursements on external debt, private nonguaranteed (PNG) (DIS, current US$)
# 97                               Disbursements on external debt, public and publicly guaranteed (PPG) (DIS, current US$)
# 98                                                                                              IDA grants (current US$)
# 99                                                                                          PPG, IBRD (DIS, current US$)
# 100                                                                                          PPG, IDA (DIS, current US$)
# 101                                                                                 PPG, multilateral (DIS, current US$)
# 102                                                                    PPG, multilateral concessional (DIS, current US$)
# 103                                                                           PPG, official creditors (DIS, current US$)
# 104                                                                                        PPG, bonds (DIS, current US$)
# 105                                                                             PPG, commercial banks (DIS, current US$)
# 106                                                                                        PNG, bonds (DIS, current US$)
# 107                                                         PNG, commercial banks and other creditors (DIS, current US$)
# 108                                                                      PPG, other private creditors (DIS, current US$)
# 109                                                                            PPG, private creditors (DIS, current US$)
# 110                                                                External debt stocks, concessional (DOD, current US$)
# 111                                                                                    PPG, bilateral (DOD, current US$)
# 112                                                                       PPG, bilateral concessional (DOD, current US$)
# 113                                                                       External debt stocks, total (DOD, current US$)
# 114                                                                   Total change in external debt stocks (current US$)
# 115                                                                                 Use of IMF credit (DOD, current US$)
# 116                                                                   External debt stocks, long-term (DOD, current US$)
# 117                                                 External debt stocks, private nonguaranteed (PNG) (DOD, current US$)
# 118                                        External debt stocks, public and publicly guaranteed (PPG) (DOD, current US$)
# 119                                                                  External debt stocks, short-term (DOD, current US$)
# 120                                                                                Debt forgiveness grants (current US$)
# 121                                                                                         PPG, IBRD (DOD, current US$)
# 122                                                                                          PPG, IDA (DOD, current US$)
# 123                                                                                 PPG, multilateral (DOD, current US$)
# 124                                                                    PPG, multilateral concessional (DOD, current US$)
# 125                                                                        IBRD loans and IDA credits (DOD, current US$)
# 126                                                                           PPG, official creditors (DOD, current US$)
# 127                                                                                        PPG, bonds (DOD, current US$)
# 128                                                                             PPG, commercial banks (DOD, current US$)
# 129                                                                                        PNG, bonds (DOD, current US$)
# 130                                                         PNG, commercial banks and other creditors (DOD, current US$)
# 131                                                                      PPG, other private creditors (DOD, current US$)
# 132                                                    External debt stocks, long-term private sector (DOD, current US$)
# 133                                                                            PPG, private creditors (DOD, current US$)
# 134                                                     External debt stocks, long-term public sector (DOD, current US$)
# 135                                                                         Present value of external debt (current US$)
# 136                                                               Residual, debt stock-flow reconciliation (current US$)
# 137                                                               External debt stocks, variable rate (DOD, current US$)
# 138                                                                                           Debt buyback (current US$)
# 139                                                                                   Debt stock reduction (current US$)
# 140                                                                                 Debt stock rescheduled (current US$)
# 141                                                                                    PPG, bilateral (INT, current US$)
# 142                                                                       PPG, bilateral concessional (INT, current US$)
# 143                                                         Interest payments on external debt, total (INT, current US$)
# 144                                                                                       IMF charges (INT, current US$)
# 145                                                     Interest payments on external debt, long-term (INT, current US$)
# 146                                   Interest payments on external debt, private nonguaranteed (PNG) (INT, current US$)
# 147                          Interest payments on external debt, public and publicly guaranteed (PPG) (INT, current US$)
# 148                                                    Interest payments on external debt, short-term (INT, current US$)
# 149                                                                                         PPG, IBRD (INT, current US$)
# 150                                                                                          PPG, IDA (INT, current US$)
# 151                                                                                 PPG, multilateral (INT, current US$)
# 152                                                                    PPG, multilateral concessional (INT, current US$)
# 153                                                                           PPG, official creditors (INT, current US$)
# 154                                                                                        PPG, bonds (INT, current US$)
# 155                                                                             PPG, commercial banks (INT, current US$)
# 156                                                                                        PNG, bonds (INT, current US$)
# 157                                                         PNG, commercial banks and other creditors (INT, current US$)
# 158                                                                      PPG, other private creditors (INT, current US$)
# 159                                                                            PPG, private creditors (INT, current US$)
# 160                                                       Interest arrears, public and publicly guaranteed (current US$)
# 161                                                                         Net change in interest arrears (current US$)
# 162                                                                   Interest arrears, official creditors (current US$)
# 163                                                                    Interest arrears, private creditors (current US$)
# 164                                                                                      Interest forgiven (current US$)
# 165                                                                     Interest rescheduled (capitalized) (current US$)
# 166                                                                         Interest rescheduled, official (current US$)
# 167                                                                          Interest rescheduled, private (current US$)
# 168                                                                    Net financial flows, bilateral (NFL, current US$)
# 169                                                                       PPG, bilateral concessional (NFL, current US$)
# 170                                                           Portfolio investment, bonds (PPG + PNG) (NFL, current US$)
# 171                                                                 Net flows on external debt, total (NFL, current US$)
# 172                                                             Net flows on external debt, long-term (NFL, current US$)
# 173                                           Net flows on external debt, private nonguaranteed (PNG) (NFL, current US$)
# 174                                  Net flows on external debt, public and publicly guaranteed (PPG) (NFL, current US$)
# 175                                                            Net flows on external debt, short-term (NFL, current US$)
# 176                                                               Net official flows from UN agencies, FAO (current US$)
# 177                                                              Net official flows from UN agencies, IAEA (current US$)
# 178                                                              Net official flows from UN agencies, IFAD (current US$)
# 179                                                               Net official flows from UN agencies, ILO (current US$)
# 180                                                             Net financial flows, IMF concessional (NFL, current US$)
# 181                                                          Net financial flows, IMF nonconcessional (NFL, current US$)
# 182                                                                         Net financial flows, IBRD (NFL, current US$)
# 183                                                                          Net financial flows, IDA (NFL, current US$)
# 184                                                                 Net financial flows, multilateral (NFL, current US$)
# 185                                                                    PPG, multilateral concessional (NFL, current US$)
# 186                                                                       Net financial flows, others (NFL, current US$)
# 187                                                                       EBRD, private nonguaranteed (NFL, current US$)
# 188                                                                        IFC, private nonguaranteed (NFL, current US$)
# 189                                                                           PPG, official creditors (NFL, current US$)
# 190                                                                                        PPG, bonds (NFL, current US$)
# 191                                                                             PPG, commercial banks (NFL, current US$)
# 192                                                    Commercial banks and other lending (PPG + PNG) (NFL, current US$)
# 193                                                                                        PNG, bonds (NFL, current US$)
# 194                                                         PNG, commercial banks and other creditors (NFL, current US$)
# 195                                                                      PPG, other private creditors (NFL, current US$)
# 196                                                                            PPG, private creditors (NFL, current US$)
# 197                                                             Net financial flows, RDB concessional (NFL, current US$)
# 198                                                          Net financial flows, RDB nonconcessional (NFL, current US$)
# 199                                                            Net official flows from UN agencies, UNAIDS (current US$)
# 200                                                            Net official flows from UN agencies, UNICEF (current US$)
# 201                                                             Net official flows from UN agencies, UNHCR (current US$)
# 202                                                              Net official flows from UN agencies, UNDP (current US$)
# 203                                                             Net official flows from UN agencies, UNECE (current US$)
# 204                                                             Net official flows from UN agencies, UNFPA (current US$)
# 205                                                             Net official flows from UN agencies, UNPBF (current US$)
# 206                                                             Net official flows from UN agencies, UNRWA (current US$)
# 207                                                              Net official flows from UN agencies, UNTA (current US$)
# 208                                                               Net official flows from UN agencies, WFP (current US$)
# 209                                                               Net official flows from UN agencies, WHO (current US$)
# 210                                                                                    PPG, bilateral (NTR, current US$)
# 211                                                                       PPG, bilateral concessional (NTR, current US$)
# 212                                                             Net transfers on external debt, total (NTR, current US$)
# 213                                                         Net transfers on external debt, long-term (NTR, current US$)
# 214                                       Net transfers on external debt, private nonguaranteed (PNG) (NTR, current US$)
# 215                              Net transfers on external debt, public and publicly guaranteed (PPG) (NTR, current US$)
# 216                                                                                         PPG, IBRD (NTR, current US$)
# 217                                                                                          PPG, IDA (NTR, current US$)
# 218                                                                                 PPG, multilateral (NTR, current US$)
# 219                                                                    PPG, multilateral concessional (NTR, current US$)
# 220                                                                           PPG, official creditors (NTR, current US$)
# 221                                                                                        PPG, bonds (NTR, current US$)
# 222                                                                             PPG, commercial banks (NTR, current US$)
# 223                                                                                        PNG, bonds (NTR, current US$)
# 224                                                         PNG, commercial banks and other creditors (NTR, current US$)
# 225                                                                      PPG, other private creditors (NTR, current US$)
# 226                                                                            PPG, private creditors (NTR, current US$)
# 227                                          Net official development assistance and official aid received (current US$)
# 228                                    Net official development assistance and official aid received (constant 2013 US$)
# 229                                                                              Net official aid received (current US$)
# 230                                                                        Net official aid received (constant 2014 US$)
# 231                                                           Net official development assistance received (current US$)
# 232                                                     Net official development assistance received (constant 2014 US$)
# 233                                                                                    PPG, bilateral (TDS, current US$)
# 234                                                                       PPG, bilateral concessional (TDS, current US$)
# 235                                                              Debt service on external debt, total (TDS, current US$)
# 236                                                                       IMF repurchases and charges (TDS, current US$)
# 237                                                          Debt service on external debt, long-term (TDS, current US$)
# 238                                        Debt service on external debt, private nonguaranteed (PNG) (TDS, current US$)
# 239                               Debt service on external debt, public and publicly guaranteed (PPG) (TDS, current US$)
# 240                                                                                         PPG, IBRD (TDS, current US$)
# 241                                                                                          PPG, IDA (TDS, current US$)
# 242                                                                         Multilateral debt service (TDS, current US$)
# 243                                                                    PPG, multilateral concessional (TDS, current US$)
# 244                                                                           PPG, official creditors (TDS, current US$)
# 245                                                                                        PPG, bonds (TDS, current US$)
# 246                                                                             PPG, commercial banks (TDS, current US$)
# 247                                                                                        PNG, bonds (TDS, current US$)
# 248                                                         PNG, commercial banks and other creditors (TDS, current US$)
# 249                                                                      PPG, other private creditors (TDS, current US$)
# 250                                                                            PPG, private creditors (TDS, current US$)
# 251                                                                       Total amount of debt rescheduled (current US$)
# 252                                                                  Undisbursed external debt, total (UND, current US$)
# 253                                                     Undisbursed external debt, official creditors (UND, current US$)
# 254                                                      Undisbursed external debt, private creditors (UND, current US$)
# 255                                         Electricity production from renewable sources, excluding hydroelectric (kWh)
# 256                            Other greenhouse gas emissions, HFC, PFC and SF6 (thousand metric tons of CO2 equivalent)
# 257                                                                Total greenhouse gas emissions (kt of CO2 equivalent)
# 258                                              Agricultural methane emissions (thousand metric tons of CO2 equivalent)
# 259                                          Methane emissions in energy sector (thousand metric tons of CO2 equivalent)
# 260                                                                             Methane emissions (kt of CO2 equivalent)
# 261                                        Agricultural nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# 262                                    Nitrous oxide emissions in energy sector (thousand metric tons of CO2 equivalent)
# 263                                                     Nitrous oxide emissions (thousand metric tons of CO2 equivalent)
# 264                                                                                             Bird species, threatened
# 265                                                                                             Fish species, threatened
# 266                                                                                   Plant species (higher), threatened
# 267                                                                                           Mammal species, threatened
# 268                                                                                 Aquaculture production (metric tons)
# 269                                                                           Capture fisheries production (metric tons)
# 270                                                                             Total fisheries production (metric tons)
# 271                                                          Annual freshwater withdrawals, total (billion cubic meters)
# 272                                                Renewable internal freshwater resources, total (billion cubic meters)
# 273                                                        Investment in energy with private participation (current US$)
# 274                                                           Investment in ICT with private participation (current US$)
# 275                                                      Investment in telecoms with private participation (current US$)
# 276                                                     Investment in transport with private participation (current US$)
# 277                                          Investment in water and sanitation with private participation (current US$)
# 278                                                       Public private partnerships investment in energy (current US$)
# 279                                                          Public private partnerships investment in ICT (current US$)
# 280                                                      Public private partnerships investment in telecom (current US$)
# 281                                                    Public private partnerships investment in transport (current US$)
# 282                                         Public private partnerships investment in water and sanitation (current US$)
# 283                                                                Industrial design applications, nonresident, by count
# 284                                                                   Industrial design applications, resident, by count
# 285                                                                                    Patent applications, nonresidents
# 286                                                                                       Patent applications, residents
# 287                                                                        Trademark applications, nonresident, by count
# 288                                                                           Trademark applications, direct nonresident
# 289                                                                              Trademark applications, direct resident
# 290                                                                           Trademark applications, resident, by count
# 291                                                                                        Trademark applications, total
# 292                                                               Air transport, registered carrier departures worldwide
# 293                                                                              Air transport, freight (million ton-km)
# 294                                                                                    Air transport, passengers carried
# 295                                                                                          Rail lines (total route-km)
# 296                                                               Container port traffic (TEU: 20 foot equivalent units)
# 297                                                                                        Mobile cellular subscriptions
# 298                                                                                        Fixed telephone subscriptions
# 299                                                                                        Fixed broadband subscriptions
# 300                                                                                              Secure Internet servers
# 301                                                                          Arms imports (SIPRI trend indicator values)
# 302                                                                                        Armed forces personnel, total
# 303                                                                          Arms exports (SIPRI trend indicator values)
# 304                                                                                            Primary education, pupils
# 305                                                                                          Primary education, teachers
# 306                                                                                      Children out of school, primary
# 307                                                                              Children out of school, primary, female
# 308                                                                                Children out of school, primary, male
# 309                                                                                          Secondary education, pupils
# 310                                                                                  Secondary education, general pupils
# 311                                                                               Secondary education, vocational pupils
# 312                                                                                        Secondary education, teachers
# 313                                                                                Secondary education, teachers, female
# 314                                                                                     Number of deaths ages 5-14 years
# 315                                                                                              Number of infant deaths
# 316                                                                                          Number of under-five deaths
# 317                                                                                            Number of neonatal deaths
# 318                                                                                            Number of maternal deaths
# 319           Number of people pushed below the $1.90 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure
# 320           Number of people pushed below the $3.10 ($ 2011 PPP) poverty line by out-of-pocket health care expenditure
# 321  Number of people spending more than 10% of household consumption or income on out-of-pocket health care expenditure
# 322  Number of people spending more than 25% of household consumption or income on out-of-pocket health care expenditure
# 323                                                                                                   Labor force, total
# 324                                                                                                        Net migration
# 325                                                                 Refugee population by country or territory of asylum
# 326                                                                 Refugee population by country or territory of origin
# 327                                                                                   International migrant stock, total
# 328                                                                                         Population ages 0-14, female
# 329                                                                                           Population ages 0-14, male
# 330                                                                                          Population ages 0-14, total
# 331                                                                                        Population ages 15-64, female
# 332                                                                                          Population ages 15-64, male
# 333                                                                                         Population ages 15-64, total
# 334                                                                                 Population ages 65 and above, female
# 335                                                                                   Population ages 65 and above, male
# 336                                                                                  Population ages 65 and above, total
# 337                                                                                                    Population, total
# 338                                                                                                   Population, female
# 339                                                                                                     Population, male
# 340                                                                                                     Rural population
# 341                                                                                                     Urban population
# 342                                                           Merchandise imports by the reporting economy (current US$)
# 343                                                           Merchandise exports by the reporting economy (current US$)
# 344                                                                                High-technology exports (current US$)
# 345                                                                             Battle-related deaths (number of people)
# 346               Internally displaced persons, new displacement associated with conflict and violence (number of cases)
# 347                           Internally displaced persons, new displacement associated with disasters (number of cases)
# 348                            Internally displaced persons, total displaced by conflict and violence (number of people)
# 349                              Presence of peace keepers (number of troops, police, and military observers in mandate)

# %% [markdown]
# ##### Only keep the indicators that are relevant to requirements i.e. Population indicators and Cellular and Broadband penetration

# %%
targetInd = simpleAggInd \
    .filter("lower(indicator_name) like '%population%total%' " + 
            " or lower(indicator_name) like '%cellular%' " +
            " or lower(indicator_name) like '%broadband%'") \
    .filter("lower(indicator_name) not like '%refugee%'")

showDF(targetInd)
# Out:
#    indicator_code                       indicator_name
# 0     IT.CEL.SETS        Mobile cellular subscriptions
# 1     IT.NET.BBND        Fixed broadband subscriptions
# 2  SP.POP.0014.TO          Population ages 0-14, total
# 3  SP.POP.1564.TO         Population ages 15-64, total
# 4  SP.POP.65UP.TO  Population ages 65 and above, total
# 5     SP.POP.TOTL                    Population, total

# %% [markdown]
# ##### Now that we have identified the various indicators of interest, we can continue with getting the metrics for these indicators

# %%
# Keep the columns that are relevant for further transformations
indData = wdiindicators \
    .withColumnRenamed("Indicator Code", "indicator_code") \
    .withColumnRenamed("Country Code", "wb_country_code") \
    .drop("Indicator Name") \
    .drop("Country Name") \
    .drop("_c62")

# %%
#Keep only the indicators that we care about
targetIndData = indData.join(targetInd, indData.indicator_code == targetInd.indicator_code).drop(targetInd.indicator_code)

# %%
showDF(targetIndData)
# Out:
#    wb_country_code  indicator_code        1960        1961        1962  \
# 0              ARB     IT.NET.BBND         NaN         NaN         NaN
# 1              ARB     IT.CEL.SETS         0.0         NaN         NaN
# 2              ARB  SP.POP.0014.TO  39900284.0  41339703.0  42792877.0
# 3              ARB  SP.POP.1564.TO  49063244.0  50032198.0  51072095.0
# 4              ARB  SP.POP.65UP.TO   3234225.0   3352609.0   3469470.0
# 5              ARB     SP.POP.TOTL  92197753.0  94724510.0  97334442.0
# 6              CSS     IT.NET.BBND         NaN         NaN         NaN
# 7              CSS     IT.CEL.SETS         0.0         NaN         NaN
# 8              CSS  SP.POP.0014.TO   1764314.0   1813810.0   1861239.0
# 9              CSS  SP.POP.1564.TO   2150293.0   2172956.0   2197694.0
# 10             CSS  SP.POP.65UP.TO    168897.0    175068.0    181750.0
# 11             CSS     SP.POP.TOTL   4194713.0   4274061.0   4353625.0
# 12             CEB     IT.NET.BBND         NaN         NaN         NaN
# 13             CEB     IT.CEL.SETS         0.0         NaN         NaN
# 14             CEB  SP.POP.0014.TO  26671417.0  26777340.0  26719172.0
# 15             CEB  SP.POP.1564.TO  58135802.0  58629074.0  59214001.0
# 16             CEB  SP.POP.65UP.TO   6594545.0   6826325.0   7076325.0
# 17             CEB     SP.POP.TOTL  91401764.0  92232738.0  93009498.0
# 18             EAR     IT.NET.BBND         NaN         NaN         NaN
# 19             EAR     IT.CEL.SETS         0.0         NaN         NaN
#
#            1963         1964         1965         1966         1967  ...  \
# 0           NaN          NaN          NaN          NaN          NaN  ...
# 1           NaN          NaN          0.0          NaN          NaN  ...
# 2    44248946.0   45685285.0   47089854.0   48668380.0   50184681.0  ...
# 3    52200457.0   53449205.0   54836642.0   56150911.0   57648467.0  ...
# 4     3584776.0    3698270.0    3809935.0    3939319.0    4066216.0  ...
# 5   100034179.0  102832760.0  105736431.0  108758610.0  111899364.0  ...
# 6           NaN          NaN          NaN          NaN          NaN  ...
# 7           NaN          NaN          0.0          NaN          NaN  ...
# 8     1905670.0    1946434.0    1983382.0    2024504.0    2062386.0  ...
# 9     2224437.0    2252267.0    2280021.0    2301102.0    2321449.0  ...
# 10     188665.0     195638.0     202721.0     208090.0     213637.0  ...
# 11    4432219.0    4508192.0    4580372.0    4648357.0    4712546.0  ...
# 12          NaN          NaN          NaN          NaN          NaN  ...
# 13          NaN          NaN          0.0          NaN          NaN  ...
# 14   26557292.0   26352149.0   26091982.0   25734869.0   25509198.0  ...
# 15   59935092.0   60731330.0   61437992.0   62201008.0   63026206.0  ...
# 16    7347635.0    7632317.0    7911012.0    8210457.0    8507867.0  ...
# 17   93840016.0   94715795.0   95440988.0   96146336.0   97043270.0  ...
# 18          NaN          NaN          NaN          NaN          NaN  ...
# 19          NaN          NaN          0.0          NaN          NaN  ...
# 4   Population ages 65 and above, total
# 5                     Population, total
# 6         Fixed broadband subscriptions
# 7         Mobile cellular subscriptions
# 8           Population ages 0-14, total
# 9          Population ages 15-64, total
# 10  Population ages 65 and above, total
# 11                    Population, total
# 12        Fixed broadband subscriptions
# 13        Mobile cellular subscriptions
# 14          Population ages 0-14, total
# 15         Population ages 15-64, total
# 16  Population ages 65 and above, total
# 17                    Population, total
# 18        Fixed broadband subscriptions
# 19        Mobile cellular subscriptions
#
# [20 rows x 65 columns]

# %% [markdown]
# ##### Let us start by getting the list of years that we have metrics for

# %%
indSample = targetIndData \
    .select(col("wb_country_code")
            , col("indicator_code")
            , lit("1960").alias("year")
            , col("1960").alias("indicator_value")) \
    .filter("indicator_value >= 0.0")

showDF(indSample)
# Out:
#    wb_country_code  indicator_code  year  indicator_value
# 0              ARB     IT.CEL.SETS  1960              0.0
# 1              ARB  SP.POP.0014.TO  1960       39900284.0
# 2              ARB  SP.POP.1564.TO  1960       49063244.0
# 3              ARB  SP.POP.65UP.TO  1960        3234225.0
# 4              ARB     SP.POP.TOTL  1960       92197753.0
# 5              CSS     IT.CEL.SETS  1960              0.0
# 6              CSS  SP.POP.0014.TO  1960        1764314.0
# 7              CSS  SP.POP.1564.TO  1960        2150293.0
# 8              CSS  SP.POP.65UP.TO  1960         168897.0
# 9              CSS     SP.POP.TOTL  1960        4194713.0
# 10             CEB     IT.CEL.SETS  1960              0.0
# 11             CEB  SP.POP.0014.TO  1960       26671417.0
# 12             CEB  SP.POP.1564.TO  1960       58135802.0
# 13             CEB  SP.POP.65UP.TO  1960        6594545.0
# 14             CEB     SP.POP.TOTL  1960       91401764.0
# 15             EAR     IT.CEL.SETS  1960              0.0
# 16             EAR  SP.POP.0014.TO  1960      403998062.0
# 17             EAR  SP.POP.1564.TO  1960      543576235.0
# 18             EAR  SP.POP.65UP.TO  1960       32429092.0
# 19             EAR     SP.POP.TOTL  1960      980003388.0

# %%
yrList = [x for x in targetIndData.schema.names \
             if x != 'wb_country_code' and x != 'indicator_code' and x != 'indicator_name'] 

print(yrList)
# Out:
# ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '_c65']

# %%
#Cheat for creating a dataframe with no rows 
indDF = indSample.filter('1 = 0')

#Iterate through the list of years and store the rows in the DataFrame we created above
for indicatorYear in yrList:
    print("Processing indicators for " + indicatorYear)
    yrIndDF = targetIndData \
        .select(col("wb_country_code")
                , col("indicator_code")
                , lit(indicatorYear).alias("year")
                , col(indicatorYear).alias("indicator_value").cast(IntegerType())) \
        .filter("indicator_value >= 0")
    indDF = indDF.union(yrIndDF)
# Out:
# Processing indicators for 1960
# Processing indicators for 1961
# Processing indicators for 1962
# Processing indicators for 1963
# Processing indicators for 1964
# Processing indicators for 1965
# Processing indicators for 1966
# Processing indicators for 1967
# Processing indicators for 1968
# Processing indicators for 1969
# Processing indicators for 1970
# Processing indicators for 1971
# Processing indicators for 1972
# Processing indicators for 1973
# Processing indicators for 1974
# Processing indicators for 1975
# Processing indicators for 1976
# Processing indicators for 1977
# Processing indicators for 1978
# Processing indicators for 1979
# Processing indicators for 1980
# Processing indicators for 1981
# Processing indicators for 1982
# Processing indicators for 1983
# Processing indicators for 1984
# Processing indicators for 1985
# Processing indicators for 1986
# Processing indicators for 1987
# Processing indicators for 1988
# Processing indicators for 1989
# Processing indicators for 1990
# Processing indicators for 1991
# Processing indicators for 1992
# Processing indicators for 1993
# Processing indicators for 1994
# Processing indicators for 1995
# Processing indicators for 1996
# Processing indicators for 1997
# Processing indicators for 1998
# Processing indicators for 1999
# Processing indicators for 2000
# Processing indicators for 2001
# Processing indicators for 2002
# Processing indicators for 2003
# Processing indicators for 2004
# Processing indicators for 2005
# Processing indicators for 2006
# Processing indicators for 2007
# Processing indicators for 2008
# Processing indicators for 2009
# Processing indicators for 2010
# Processing indicators for 2011
# Processing indicators for 2012
# Processing indicators for 2013
# Processing indicators for 2014
# Processing indicators for 2015
# Processing indicators for 2016
# Processing indicators for 2017
# Processing indicators for 2018
# Processing indicators for 2019
# Processing indicators for 2020
# Processing indicators for _c65

# %%
indDF.printSchema()
# Out:
# root
#  |-- wb_country_code: string (nullable = true)
#  |-- indicator_code: string (nullable = true)
#  |-- year: string (nullable = false)
#  |-- indicator_value: double (nullable = true)

# %%
indDF.count()
# Out:
# 75040

# %%
yrPivot = indDF.groupBy('year').pivot('indicator_code').sum('indicator_value')

# %%
showDF(yrPivot.orderBy('year'))
# Out:
#     year  IT.CEL.SETS  IT.NET.BBND  SP.POP.0014.TO  SP.POP.1564.TO  \
# 0   1960          0.0          NaN    1.166309e+10    1.758573e+10
# 1   1961          NaN          NaN    1.188233e+10    1.774670e+10
# 2   1962          NaN          NaN    1.217369e+10    1.797404e+10
# 3   1963          NaN          NaN    1.251664e+10    1.828305e+10
# 4   1964          NaN          NaN    1.283348e+10    1.862509e+10
# 5   1965          0.0          NaN    1.311915e+10    1.901574e+10
# 6   1966          NaN          NaN    1.344689e+10    1.938029e+10
# 7   1967          NaN          NaN    1.372431e+10    1.979268e+10
# 8   1968          NaN          NaN    1.397466e+10    2.024609e+10
# 9   1969          NaN          NaN    1.422940e+10    2.073197e+10
# 10  1970          0.0          NaN    1.449223e+10    2.122218e+10
# 11  1971          NaN          NaN    1.478937e+10    2.168581e+10
# 12  1972          NaN          NaN    1.507135e+10    2.211291e+10
# 13  1973          NaN          NaN    1.534009e+10    2.254923e+10
# 14  1974          NaN          NaN    1.558801e+10    2.300643e+10
# 15  1975          0.0          NaN    1.580300e+10    2.347975e+10
# 16  1976          0.0          NaN    1.601585e+10    2.393315e+10
# 17  1977          0.0          NaN    1.619749e+10    2.441223e+10
# 18  1978          0.0          NaN    1.635882e+10    2.492327e+10
# 19  1979          0.0          NaN    1.651076e+10    2.546480e+10
#
#     SP.POP.65UP.TO   SP.POP.TOTL
# 0     1.409319e+09  2.953207e+10
# 1     1.441242e+09  2.984400e+10
# 2     1.473262e+09  3.022931e+10
# 3     1.506747e+09  3.068790e+10
# 4     1.538687e+09  3.115021e+10
# 5     1.570263e+09  3.162321e+10
# 6     1.623280e+09  3.210529e+10
# 7     1.675977e+09  3.255040e+10
# 8     1.728541e+09  3.300198e+10
# 9     1.781782e+09  3.347741e+10
# 10    1.833979e+09  3.395721e+10
# 11    1.898023e+09  3.445001e+10
# 12    1.959648e+09  3.493755e+10
# 13    2.019352e+09  3.542113e+10
# 14    2.079052e+09  3.590887e+10
# 15    2.138353e+09  3.638839e+10
# 16    2.209800e+09  3.685982e+10
# 17    2.281328e+09  3.733133e+10
# 18    2.351393e+09  3.781137e+10
# 19    2.416409e+09  3.830323e+10

# %%
yrPivot.printSchema()
# Out:
# root
#  |-- year: string (nullable = false)
#  |-- IT.CEL.SETS: double (nullable = true)
#  |-- IT.NET.BBND: double (nullable = true)
#  |-- SP.POP.0014.TO: double (nullable = true)
#  |-- SP.POP.1564.TO: double (nullable = true)
#  |-- SP.POP.65UP.TO: double (nullable = true)
#  |-- SP.POP.TOTL: double (nullable = true)

# %%
yrPivotDF = yrPivot.orderBy('year') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population')

# %%
wdicountryDimFinal = wdicountryDim.filter("country_iso_code is not null")

showDF(wdicountryDimFinal)
# Out:
#    country_iso_code wb_country_code          country_name  \
# 0                AW             ABW                 Aruba
# 1                AF             AFG           Afghanistan
# 2                AO             AGO                Angola
# 3                AL             ALB               Albania
# 4                AD             AND               Andorra
# 5                1A             ARB            Arab World
# 6                AE             ARE  United Arab Emirates
# 7                AR             ARG             Argentina
# 8                AM             ARM               Armenia
# 9                AS             ASM        American Samoa
# 10               AG             ATG   Antigua and Barbuda
# 11               AU             AUS             Australia
# 12               AT             AUT               Austria
# 13               AZ             AZE            Azerbaijan
# 14               BI             BDI               Burundi
# 15               BE             BEL               Belgium
# 16               BJ             BEN                 Benin
# 17               BF             BFA          Burkina Faso
# 18               BD             BGD            Bangladesh
# 19               BG             BGR              Bulgaria
#
#                   country_long_name                      region  \
# 0                             Aruba   Latin America & Caribbean
# 1      Islamic State of Afghanistan                  South Asia
# 2       People's Republic of Angola          Sub-Saharan Africa
# 3               Republic of Albania       Europe & Central Asia
# 4           Principality of Andorra       Europe & Central Asia
# 5                        Arab World                        None
# 6              United Arab Emirates  Middle East & North Africa
# 7                Argentine Republic                        None
# 8               Republic of Armenia       Europe & Central Asia
# 9                    American Samoa         East Asia & Pacific
# 10              Antigua and Barbuda   Latin America & Caribbean
# 11        Commonwealth of Australia         East Asia & Pacific
# 12              Republic of Austria       Europe & Central Asia
# 13           Republic of Azerbaijan       Europe & Central Asia
# 14              Republic of Burundi          Sub-Saharan Africa
# 15               Kingdom of Belgium       Europe & Central Asia
# 16                Republic of Benin          Sub-Saharan Africa
# 17                     Burkina Faso          Sub-Saharan Africa
# 18  People's Republic of Bangladesh                  South Asia
# 19             Republic of Bulgaria       Europe & Central Asia
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7                  None
# 8   Lower middle income
# 9   Upper middle income
# 10          High income
# 11          High income
# 12          High income
# 13  Upper middle income
# 14           Low income
# 15          High income
# 16           Low income
# 17           Low income
# 18  Lower middle income
# 19  Upper middle income

# %%
regionalInd = indDF.join(wdicountryDimFinal
                                       , indDF.wb_country_code == wdicountryDim.wb_country_code
                                       , "inner") \
    .select(wdicountryDim.region
            , indDF.wb_country_code
            , indDF.year
            , indDF.indicator_code
            , indDF.indicator_value)

# %%
showDF(regionalInd)
# Out:
#    region wb_country_code  year  indicator_code  indicator_value
# 0    None             ARB  1960     IT.CEL.SETS              0.0
# 1    None             ARB  1960  SP.POP.0014.TO       39900284.0
# 2    None             ARB  1960  SP.POP.1564.TO       49063244.0
# 3    None             ARB  1960  SP.POP.65UP.TO        3234225.0
# 4    None             ARB  1960     SP.POP.TOTL       92197753.0
# 5    None             CSS  1960     IT.CEL.SETS              0.0
# 6    None             CSS  1960  SP.POP.0014.TO        1764314.0
# 7    None             CSS  1960  SP.POP.1564.TO        2150293.0
# 8    None             CSS  1960  SP.POP.65UP.TO         168897.0
# 9    None             CSS  1960     SP.POP.TOTL        4194713.0
# 10   None             CEB  1960     IT.CEL.SETS              0.0
# 11   None             CEB  1960  SP.POP.0014.TO       26671417.0
# 12   None             CEB  1960  SP.POP.1564.TO       58135802.0
# 13   None             CEB  1960  SP.POP.65UP.TO        6594545.0
# 14   None             CEB  1960     SP.POP.TOTL       91401764.0
# 15   None             EAR  1960     IT.CEL.SETS              0.0
# 16   None             EAR  1960  SP.POP.0014.TO      403998062.0
# 17   None             EAR  1960  SP.POP.1564.TO      543576235.0
# 18   None             EAR  1960  SP.POP.65UP.TO       32429092.0
# 19   None             EAR  1960     SP.POP.TOTL      980003388.0

# %%
regionalPivot = regionalInd.groupBy('region', 'year').pivot('indicator_code').sum('indicator_value')

# %%
showDF(regionalPivot.orderBy('region', 'year'), limitRows=100)
# Out:
#                  region  year   IT.CEL.SETS   IT.NET.BBND  SP.POP.0014.TO  \
# 0                  None  1960  0.000000e+00           NaN    1.054993e+10
# %% [markdown]
# ##### Regional metrics for each year and country

# %%
countryInd = indDF.join(wdicountryDimFinal
                                       , indDF.wb_country_code == wdicountryDim.wb_country_code
                                       , "inner") \
    .select(indDF.wb_country_code
            , wdicountryDim.country_iso_code
            , wdicountryDim.country_name
            , indDF.year
            , indDF.indicator_code
            , indDF.indicator_value)

showDF(countryInd)
# Out:
#    wb_country_code country_iso_code                    country_name  year  \
# 0              ARB               1A                      Arab World  1960
# 1              ARB               1A                      Arab World  1960
# 2              ARB               1A                      Arab World  1960
# 3              ARB               1A                      Arab World  1960
# 4              ARB               1A                      Arab World  1960
# 5              CSS               S3          Caribbean small states  1960
# 6              CSS               S3          Caribbean small states  1960
# 7              CSS               S3          Caribbean small states  1960
# 8              CSS               S3          Caribbean small states  1960
# 9              CSS               S3          Caribbean small states  1960
# 10             CEB               B8  Central Europe and the Baltics  1960
# 11             CEB               B8  Central Europe and the Baltics  1960
# 12             CEB               B8  Central Europe and the Baltics  1960
# 13             CEB               B8  Central Europe and the Baltics  1960
# 14             CEB               B8  Central Europe and the Baltics  1960
# 15             EAR               V2      Early-demographic dividend  1960
# 16             EAR               V2      Early-demographic dividend  1960
# 17             EAR               V2      Early-demographic dividend  1960
# 18             EAR               V2      Early-demographic dividend  1960
# 19             EAR               V2      Early-demographic dividend  1960
#
#     indicator_code  indicator_value
# 0      IT.CEL.SETS              0.0
# 1   SP.POP.0014.TO       39900284.0
# 2   SP.POP.1564.TO       49063244.0
# 3   SP.POP.65UP.TO        3234225.0
# 4      SP.POP.TOTL       92197753.0
# 5      IT.CEL.SETS              0.0
# 6   SP.POP.0014.TO        1764314.0
# 7   SP.POP.1564.TO        2150293.0
# 8   SP.POP.65UP.TO         168897.0
# 9      SP.POP.TOTL        4194713.0
# 10     IT.CEL.SETS              0.0
# 11  SP.POP.0014.TO       26671417.0
# 12  SP.POP.1564.TO       58135802.0
# 13  SP.POP.65UP.TO        6594545.0
# 14     SP.POP.TOTL       91401764.0
# 15     IT.CEL.SETS              0.0
# 16  SP.POP.0014.TO      403998062.0
# 17  SP.POP.1564.TO      543576235.0
# 18  SP.POP.65UP.TO       32429092.0
# 19     SP.POP.TOTL      980003388.0

# %%
countryPivot = countryInd.groupBy('country_iso_code', 'country_name', 'year') \
    .pivot('indicator_code').sum('indicator_value')

# %%
showDF(countryPivot.orderBy('country_iso_code', 'country_name', 'year'), limitRows=100)
# Out:
#    country_iso_code country_name  year  IT.CEL.SETS  IT.NET.BBND  \
# 0                1A   Arab World  1960          0.0          NaN
# 1                1A   Arab World  1961          NaN          NaN
# 2                1A   Arab World  1962          NaN          NaN
# 3                1A   Arab World  1963          NaN          NaN
# 4                1A   Arab World  1964          NaN          NaN
# 5                1A   Arab World  1965          0.0          NaN
# 6                1A   Arab World  1966          NaN          NaN
# 7                1A   Arab World  1967          NaN          NaN
# 8                1A   Arab World  1968          NaN          NaN
# 9                1A   Arab World  1969          NaN          NaN
# 10               1A   Arab World  1970          0.0          NaN
# 11               1A   Arab World  1971          NaN          NaN
# 12               1A   Arab World  1972          NaN          NaN
# 13               1A   Arab World  1973          NaN          NaN
# 14               1A   Arab World  1974          NaN          NaN
# 15               1A   Arab World  1975          0.0          NaN
# 16               1A   Arab World  1976          0.0          NaN
# 17               1A   Arab World  1977          0.0          NaN
# 18               1A   Arab World  1978          0.0          NaN
# 19               1A   Arab World  1979          0.0          NaN
# 20               1A   Arab World  1980          0.0          NaN
# 21               1A   Arab World  1981          0.0          NaN
# 22               1A   Arab World  1982       2330.0          NaN
# 23               1A   Arab World  1983       3564.0          NaN
# 24               1A   Arab World  1984       4936.0          NaN
# 25               1A   Arab World  1985       7976.0          NaN
# 26               1A   Arab World  1986      20756.0          NaN
# 27               1A   Arab World  1987      33793.0          NaN
# 28               1A   Arab World  1988      39447.0          NaN
# 29               1A   Arab World  1989      58750.0          NaN
# 30               1A   Arab World  1990      88618.0          NaN
# 31               1A   Arab World  1991     129904.0          NaN
# 32               1A   Arab World  1992     152281.0          NaN
# 33               1A   Arab World  1993     199350.0          NaN
# 34               1A   Arab World  1994     263401.0          NaN
# 35               1A   Arab World  1995     501551.0          NaN
# 36               1A   Arab World  1996     921229.0          NaN
# 37               1A   Arab World  1997    1616551.0          NaN
# 38               1A   Arab World  1998    2523542.0          NaN
# 39               1A   Arab World  1999    4105508.0          NaN
# 40               1A   Arab World  2000    9035245.0          NaN
# 41               1A   Arab World  2001   16679592.0          NaN
# 42               1A   Arab World  2002   25275670.0          NaN
# 43               1A   Arab World  2003   35121264.0          NaN
# 44               1A   Arab World  2004   52132880.0     365943.0
# 45               1A   Arab World  2005   84854578.0     861800.0
# 46               1A   Arab World  2006  125958920.0    1545503.0
# 47               1A   Arab World  2007  174488123.0    2811961.0
# 48               1A   Arab World  2008  214062659.0    4291118.0
# 49               1A   Arab World  2009  265270942.0    5945601.0
# 50               1A   Arab World  2010  312247811.0    7179449.0
# 51               1A   Arab World  2011  351957917.0    8573908.0
# 52               1A   Arab World  2012  381641879.0   10326701.0
# 53               1A   Arab World  2013  407704583.0   11423551.0
# 54               1A   Arab World  2014  415029269.0   13345099.0
# 55               1A   Arab World  2015  419014176.0   19216253.0
# 56               1A   Arab World  2016  417212275.0   21308222.0
# 57               1A   Arab World  2017  416484296.0   29518910.0
# 58               1A   Arab World  2018  420743880.0   30683979.0
# 59               1A   Arab World  2019  423703965.0   33227417.0
# 60               1W        World  1960          0.0          NaN
# 61               1W        World  1961          NaN          NaN
# 62               1W        World  1962          NaN          NaN
# 63               1W        World  1963          NaN          NaN
# 64               1W        World  1964          NaN          NaN
# 65               1W        World  1965          0.0          NaN
# 66               1W        World  1966          NaN          NaN
# 67               1W        World  1967          NaN          NaN
# 68               1W        World  1968          NaN          NaN
# 69               1W        World  1969          NaN          NaN
# 70               1W        World  1970          0.0          NaN
# 71               1W        World  1971          NaN          NaN
# 72               1W        World  1972          NaN          NaN
# 73               1W        World  1973          NaN          NaN
# 74               1W        World  1974          NaN          NaN
# 72    1.433034e+09    2.147484e+09     208145544.0  2.147484e+09
# 73    1.456473e+09    2.147484e+09     214275772.0  2.147484e+09
# 74    1.477990e+09    2.147484e+09     220445208.0  2.147484e+09
# 75    1.496244e+09    2.147484e+09     226568971.0  2.147484e+09
# 76    1.514175e+09    2.147484e+09     233893569.0  2.147484e+09
# 77    1.529013e+09    2.147484e+09     241259332.0  2.147484e+09
# 78    1.541823e+09    2.147484e+09     248490419.0  2.147484e+09
# 79    1.553823e+09    2.147484e+09     255202292.0  2.147484e+09
# 80    1.565437e+09    2.147484e+09     261099059.0  2.147484e+09
# 81    1.577942e+09    2.147484e+09     267265264.0  2.147484e+09
# 82    1.592062e+09    2.147484e+09     272476835.0  2.147484e+09
# 83    1.606565e+09    2.147484e+09     277139785.0  2.147484e+09
# 84    1.620600e+09    2.147484e+09     281896206.0  2.147484e+09
# 85    1.634815e+09    2.147484e+09     287241476.0  2.147484e+09
# 86    1.655399e+09    2.147484e+09     294145832.0  2.147484e+09
# 87    1.675818e+09    2.147484e+09     301409882.0  2.147484e+09
# 88    1.695930e+09    2.147484e+09     309006726.0  2.147484e+09
# 89    1.715235e+09    2.147484e+09     316916003.0  2.147484e+09
# 90    1.734028e+09    2.147484e+09     325174848.0  2.147484e+09
# 91    1.756492e+09    2.147484e+09     334523210.0  2.147484e+09
# 92    1.773060e+09    2.147484e+09     344135004.0  2.147484e+09
# 93    1.786795e+09    2.147484e+09     353851435.0  2.147484e+09
# 94    1.799275e+09    2.147484e+09     363255788.0  2.147484e+09
# 95    1.811869e+09    2.147484e+09     372220037.0  2.147484e+09
# 96    1.818373e+09    2.147484e+09     382704217.0  2.147484e+09
# 97    1.827837e+09    2.147484e+09     392273227.0  2.147484e+09
# 98    1.837346e+09    2.147484e+09     401350311.0  2.147484e+09
# 99    1.842898e+09    2.147484e+09     410527906.0  2.147484e+09

# %%
recentInd = indData \
    .select("wb_country_code", "indicator_code", "2019") \
    .filter(col('indicator_code').isin('IC.REG.COST.PC.ZS', 'IC.REG.DURS', 'IC.REG.PROC', \
        'NY.GNP.ATLS.CD', 'NY.GDP.MKTP.KD', 'NY.GDP.PCAP.KD', 'IQ.CPA.BREG.XQ', 'IC.BUS.EASE.XQ')) \
    .withColumnRenamed("2019", "indicator_value") \
    .withColumn("indicator_value", col("indicator_value").cast(DecimalType(38, 2)))

showDF(recentInd)
# Out:
#    wb_country_code     indicator_code   indicator_value
# 0              ARB  IC.REG.COST.PC.ZS             27.80
# 1              ARB     IQ.CPA.BREG.XQ              2.42
# 2              ARB     IC.BUS.EASE.XQ              None
# 3              ARB     NY.GDP.MKTP.KD  2750603986533.94
# 4              ARB     NY.GDP.PCAP.KD           6428.59
# 5              ARB     NY.GNP.ATLS.CD  2777310723208.36
# 6              ARB        IC.REG.PROC              6.64
# 7              ARB        IC.REG.DURS             19.65
# 8              CSS  IC.REG.COST.PC.ZS             18.08
# 9              CSS     IQ.CPA.BREG.XQ              3.20
# 10             CSS     IC.BUS.EASE.XQ              None
# 11             CSS     NY.GDP.MKTP.KD    68816032575.97
# 12             CSS     NY.GDP.PCAP.KD           9297.73
# 13             CSS     NY.GNP.ATLS.CD    74667625354.04
# 14             CSS        IC.REG.PROC              6.62
# 15             CSS        IC.REG.DURS             19.65
# 16             CEB  IC.REG.COST.PC.ZS              2.61
# 17             CEB     IQ.CPA.BREG.XQ              None
# 18             CEB     IC.BUS.EASE.XQ              None
# 19             CEB     NY.GDP.MKTP.KD  1739248634624.54

# %%
businessIndexInd = indData \
    .select("wb_country_code", "indicator_code", "2020") \
    .filter(col('indicator_code').isin('IC.BUS.EASE.XQ')) \
    .withColumnRenamed("2020", "indicator_value") \
    .withColumn("indicator_value", col("indicator_value").cast(DecimalType(38, 2)))

# %%
allInd = recentInd.union(businessIndexInd)

# %%
countryBusinessStrtupPivot = allInd.join(wdicountryDimFinal
                                       , recentInd.wb_country_code == wdicountryDim.wb_country_code
                                       , "inner") \
    .select(wdicountryDimFinal.country_iso_code
            , wdicountryDimFinal.country_name
            , recentInd.indicator_code
            , recentInd.indicator_value) \
    .groupBy('country_iso_code', 'country_name').pivot('indicator_code').sum('indicator_value') \
    .withColumnRenamed('country_iso_code', 'Country ISO Code') \
    .withColumnRenamed('country_name', 'Country Name') \
    .withColumnRenamed('NY.GNP.ATLS.CD', 'GNI') \
    .withColumnRenamed('IC.REG.DURS', 'Startup Time') \
    .withColumnRenamed('IC.REG.PROC', 'Startup Procedures') \
    .withColumnRenamed('IC.REG.COST.PC.ZS', 'Startup Cost Pct of GNI') \
    .withColumnRenamed('NY.GDP.MKTP.KD', 'GDP') \
    .withColumnRenamed('NY.GDP.PCAP.KD', 'GDP Per Capita') \
    .withColumnRenamed('IQ.CPA.BREG.XQ', 'Business Regulation') \
    .withColumnRenamed('IC.BUS.EASE.XQ', 'Ease of business') \
    .withColumn('Startup Cost', (col('GNI') * col('Startup Cost Pct of GNI') / lit(100.0)).cast(DecimalType(38, 2))) \
    .filter(col('GNI') > 0) \
    .filter(col('Startup Time').isNotNull()) \
    .filter(col('Startup Procedures').isNotNull()) \
    .filter(col('Startup Cost').isNotNull())

# %%
showDF(countryBusinessStrtupPivot, limitRows = 500)
# Out:
#     Country ISO Code                                       Country Name  \
# 0                 BJ                                              Benin
# 1                 XC                                          Euro area
# 2                 LY                                              Libya
# 3                 KZ                                         Kazakhstan
# 4                 JM                                            Jamaica
# 5                 NO                                             Norway
# 6                 AG                                Antigua and Barbuda
# 7                 CG                                              Congo
# 8                 AR                                          Argentina
# 9                 HT                                              Haiti
# 10                QA                                              Qatar
# 11                EU                                     European Union
# 12                XE             Heavily indebted poor countries (HIPC)
# 13                BB                                           Barbados
# 14                LT                                          Lithuania
# 15                SL                                       Sierra Leone
# 16                S4                                 Other small states
# 17                OM                                               Oman
# 18                PK                                           Pakistan
# 19                SK                                    Slovak Republic
# 20                CN                                              China
# 21                T2             Latin America & Caribbean (IDA & IBRD)
# 22                SN                                            Senegal
# 23                MY                                           Malaysia
# 24                BO                                            Bolivia
# 25                SA                                       Saudi Arabia
# 26                IL                                             Israel
# 27                V4                          Post-demographic dividend
# 28                MT                                              Malta
# 29                XN                                Lower middle income
# 30                CL                                              Chile
# 31                ZF         Sub-Saharan Africa (excluding high income)
# 32                JP                                              Japan
# 33                DZ                                            Algeria
# 34                T5                            South Asia (IDA & IBRD)
# 35                KN                                St. Kitts and Nevis
# 36                VC                     St. Vincent and the Grenadines
# 37                TD                                               Chad
# 38                ZT                                   IDA & IBRD total
# 39                LR                                            Liberia
# 40                7E      Europe & Central Asia (excluding high income)
# 41                ML                                               Mali
# 42                SV                                        El Salvador
# 43                KG                                    Kyrgyz Republic
# 44                HU                                            Hungary
# 45                TJ                                         Tajikistan
# 46                XO                                Low & middle income
# 47                NE                                              Niger
# 48                MD                                            Moldova
# 49                TR                                             Turkey
# 50                XD                                        High income
# 51                LU                                         Luxembourg
# 52                AM                                            Armenia
# 53                V2                         Early-demographic dividend
# 54                TO                                              Tonga
# 55                TH                                           Thailand
# 56                XG                                          IDA total
# 57                OE                                       OECD members
# 58                VN                                            Vietnam
# 59                ID                                          Indonesia
# 60                SE                                             Sweden
# 61                MZ                                         Mozambique
# 62                CR                                         Costa Rica
# 63                HK                               Hong Kong SAR, China
# 64                NZ                                        New Zealand
# 65                GM                                         The Gambia
# 66                IE                                            Ireland
# 67                PA                                             Panama
# 68                CY                                             Cyprus
# 69                NA                                            Namibia
# 70                KI                                           Kiribati
# 71                CD                                    Dem. Rep. Congo
# 72                SG                                          Singapore
# 73                SR                                           Suriname
# 74                GE                                            Georgia
# 75                UY                                            Uruguay
# 76                UZ                                         Uzbekistan
# 77                ZG                                 Sub-Saharan Africa
# 78                PL                                             Poland
# 79                XF                                          IBRD only
# 80                HR                                            Croatia
# 81                JO                                             Jordan
# 82                EC                                            Ecuador
# 83                DE                                            Germany
# 84                WS                                              Samoa
# 85                Z7                              Europe & Central Asia
# 86                HN                                           Honduras
# 87                MR                                         Mauritania
# 88                BS                                        The Bahamas
# 89                T6                    Sub-Saharan Africa (IDA & IBRD)
# 90                MG                                         Madagascar
# 91                FR                                             France
# 92                LB                                            Lebanon
# 93                XL       Least developed countries: UN classification
# 94                BH                                            Bahrain
# 95                RW                                             Rwanda
# 96                TT                                Trinidad and Tobago
# 97                TZ                                           Tanzania
# 98                VU                                            Vanuatu
# 99                NP                                              Nepal
# 100               F1           Fragile and conflict affected situations
# 101               SZ                                          Swaziland
# 102               ZQ                         Middle East & North Africa
# 103               GN                                             Guinea
# 104               NL                                        Netherlands
# 105               XK                                             Kosovo
# 106               AO                                             Angola
# 107               ZJ                          Latin America & Caribbean
# 108               BW                                           Botswana
# 109               Z4                                East Asia & Pacific
# 110               T4                   East Asia & Pacific (IDA & IBRD)
# 111               IQ                                               Iraq
# 112               XP                                      Middle income
# 113               PH                                        Philippines
# 114               S3                             Caribbean small states
# 115               GB                                     United Kingdom
# 116               DJ                                           Djibouti
# 117               XT                                Upper middle income
# 118               EE                                            Estonia
# 119               CZ                                     Czech Republic
# 120               AU                                          Australia
# 121               SB                                    Solomon Islands
# 122               MM                                            Myanmar
# 123               AF                                        Afghanistan
# 124               DK                                            Denmark
# 125               AE                               United Arab Emirates
# 126               BD                                         Bangladesh
# 127               ET                                           Ethiopia
# 128               V3                          Late-demographic dividend
# 129               GR                                             Greece
# 130               US                                      United States
# 131               FI                                            Finland
# 132               DM                                           Dominica
# 133               ME                                         Montenegro
# 134               T7                 Europe & Central Asia (IDA & IBRD)
# 135               XI                                           IDA only
# 136               KR                                              Korea
# 137               S2                        Pacific island small states
# 138               ZW                                           Zimbabwe
# 139               ZM                                             Zambia
# 140               CA                                             Canada
# 141               BN                                             Brunei
# 142               GA                                              Gabon
# 143               BR                                             Brazil
# 144               XM                                         Low income
# 145               XJ  Latin America & Caribbean (excluding high income)
# 146               BF                                       Burkina Faso
# 147               MW                                             Malawi
# 148               4E        East Asia & Pacific (excluding high income)
# 149               BZ                                             Belize
# 150               NI                                          Nicaragua
# 151               BG                                           Bulgaria
# 152               1A                                         Arab World
# 153               PT                                           Portugal
# 154               MV                                           Maldives
# 155               BY                                            Belarus
# 156               IN                                              India
# 157               ST                              São Tomé and Principe
# 158               LV                                             Latvia
# 159               SD                                              Sudan
# 160               LA                                            Lao PDR
# 161               RU                                             Russia
# 162               CM                                           Cameroon
# 163               UG                                             Uganda
# 164               CF                           Central African Republic
# 165               BT                                             Bhutan
# 166               V1                           Pre-demographic dividend
# 167               CV                                         Cabo Verde
# 168               XH                                          IDA blend
# 169               IS                                            Iceland
# 170               KM                                            Comoros
# 171               CO                                           Colombia
# 172               LS                                            Lesotho
# 173               PW                                              Palau
# 174               TL                                        Timor-Leste
# 175               PE                                               Peru
# 176               GT                                          Guatemala
# 177               MU                                          Mauritius
# 178               S1                                       Small states
# 179               ZA                                       South Africa
# 180               ES                                              Spain
# 181               BI                                            Burundi
# 182               TG                                               Togo
# 183               LK                                          Sri Lanka
# 184               GY                                             Guyana
# 185               RO                                            Romania
# 186               MN                                           Mongolia
# 187               LC                                          St. Lucia
# 188               NG                                            Nigeria
# 189               RS                                             Serbia
# 190               BE                                            Belgium
# 191               GH                                              Ghana
# 192               KE                                              Kenya
# 193               GQ                                  Equatorial Guinea
# 194               PR                                        Puerto Rico
# 195               AZ                                         Azerbaijan
# 196               PG                                   Papua New Guinea
# 197               8S                                         South Asia
# 198               MA                                            Morocco
# 199               UA                                            Ukraine
# 200               SC                                         Seychelles
# 201               EG                                              Egypt
# 202               GD                                            Grenada
# 203               PY                                           Paraguay
# 204               BA                             Bosnia and Herzegovina
# 205               FJ                                               Fiji
# 206               GW                                      Guinea-Bissau
# 207               MK                                          Macedonia
# 208               MX                                             Mexico
# 209               DO                                 Dominican Republic
# 210               TN                                            Tunisia
# 211               KH                                           Cambodia
# 212               IT                                              Italy
# 213               CH                                        Switzerland
# 214               B8                     Central Europe and the Baltics
# 215               1W                                              World
# 216               CI                                      Côte d'Ivoire
# 217               AT                                            Austria
# 218               SI                                           Slovenia
# 219               XU                                      North America
# 220               AL                                            Albania
#
#     Ease of business Startup Cost Pct of GNI Startup Time Startup Procedures  \
# 0             149.00                    3.50         8.50               6.00
# 1               None                    3.21         9.82               5.05
# 2             186.00                   24.60        35.00              10.00
# 3              25.00                    0.20         5.00               4.00
# 4              71.00                    4.20         3.00               2.00
# 5               9.00                    0.80         4.00               4.00
# 6             113.00                    8.00        19.00               9.00
# 7             180.00                   62.20        49.50              11.00
# 8             126.00                    5.00        11.50              12.00
# 9             179.00                  179.70        97.00              12.00
# 10             77.00                    6.30         8.70               8.00
# 11              None                    3.20        12.17               5.37
# 12              None                   44.37        22.54               7.26
# 13            128.00                    7.30        16.00               7.00
# 14             11.00                    0.50         5.50               4.00
# 15            163.00                    7.60         8.00               5.00
# 16              None                   15.83        15.58               7.23
# 17             68.00                    3.10         4.30               4.00
# 18            108.00                    6.70        16.50               5.00
# 19             45.00                    1.00        21.50               7.00
# 20             31.00                    1.10         8.50               4.00
# 21              None                   32.97        29.80               8.20
# 22            123.00                   22.60         6.00               4.00
# 23             12.00                   11.10        17.50               8.00
# 24            150.00                   37.30        39.50              12.00
# 25             62.00                    5.40        10.40               3.00
# 26             35.00                    2.70        11.00               3.00
# 27              None                    3.43        11.19               5.33
# 28             88.00                    6.70        20.50               5.00
# 29              None                   23.48        22.15               7.36
# 30             59.00                    2.70         4.00               6.00
# 31              None                   37.59        21.67               7.59
# 32             29.00                    7.50        11.10               8.00
# 33            157.00                   11.30        18.00              12.00
# 34              None                    8.26        14.56               7.13
# 35            139.00                    6.20        18.50               7.00
# 36            130.00                   13.90        10.00               7.00
# 37            182.00                  169.30        58.00               8.00
# 38              None                   25.31        22.97               7.21
# 39            175.00                    6.30        18.00               5.00
# 40              None                    3.73        11.35               4.95
# 41            148.00                   55.10        11.00               5.00
# 42             91.00                   43.30        16.50               9.00
# 43             80.00                    1.40        10.00               4.00
# 44             52.00                    4.50         7.00               6.00
# 45            106.00                   17.50         7.00               3.00
# 46              None                   27.14        23.66               7.29
# 47            132.00                    7.90        10.00               4.00
# 48             48.00                    4.00         4.00               3.00
# 49             33.00                    6.00         7.00               7.00
# 50              None                    4.09        10.93               5.21
# 51             72.00                    1.60        16.50               5.00
# 52             47.00                    0.80         4.00               3.00
# 53              None                   28.18        30.83               7.95
# 54            103.00                    6.00        16.00               4.00
# 55             21.00                    3.00         6.00               5.00
# 56              None                   34.33        22.53               6.85
# 57              None                    3.69         9.11               5.08
# 58             70.00                    5.60        16.00               8.00
# 59             73.00                    5.70        12.60              11.00
# 60             10.00                    0.50         7.50               4.00
# 61            138.00                  106.90        17.00              10.00
# 62             74.00                    9.60        23.00              10.00
# 63              3.00                    0.50         1.50               2.00
# 64              1.00                    0.20         0.50               1.00
# 65            155.00                   49.50         8.00               6.00
# 66             24.00                    0.10        11.00               3.00
# 67             86.00                    5.80         6.00               5.00
# 68             54.00                    5.60         6.00               5.00
# 69            104.00                    8.90        54.00              10.00
# 70            164.00                   34.90        31.00               7.00
# 71            183.00                   16.30         7.00               4.00
# 72              2.00                    0.40         1.50               2.00
# 73            162.00                   93.50        66.00               8.00
# 74              7.00                    2.10         1.00               1.00
# 75            101.00                   24.10         6.50               5.00
# 76             69.00                    2.20         3.00               3.00
# 77              None                   36.30        21.53               7.54
# 78             40.00                   11.60        37.00               5.00
# 79              None                   15.62        23.44               7.59
# 80             51.00                    6.20        19.50               7.00
# 81             75.00                   23.30        12.50               7.00
# 82            129.00                   33.00        48.50              11.00
# 83             22.00                    6.50         8.00               9.00
# 84             98.00                    6.90         9.00               4.00
# 85              None                    3.31        11.76               5.26
# 86            133.00                   28.10        42.00              11.00
# 87            152.00                   15.80         6.00               4.00
# 88            119.00                   11.00        11.50               7.00
# 89              None                   36.30        21.53               7.54
# 90            161.00                   30.20         8.00               5.00
# 91             32.00                    0.70         4.00               5.00
# 92            143.00                   42.30        15.00               8.00
# 93              None                   40.70        26.22               7.20
# 94             43.00                    1.00         8.30               6.00
# 95             38.00                    0.00         4.00               5.00
# 96            105.00                    0.70        10.50               7.00
# 97            141.00                   40.60        29.50              10.00
# 98            107.00                   42.50        18.00               7.00
# 99             94.00                   20.20        22.50               8.00
# 100             None                   54.86        34.61               7.76
# 101           121.00                   10.70        21.50              12.00
# 102             None                   16.00        19.52               6.29
# 103           156.00                   33.80        15.00               6.00
# 104            42.00                    4.00         3.50               4.00
# 105            57.00                    1.40         4.50               3.00
# 106           177.00                   11.10        36.00               8.00
# 107             None                   30.56        28.09               8.06
# 108            87.00                    0.60        48.00               9.00
# 109             None                   15.77        22.85               6.14
# 110             None                   20.49        29.65               7.29
# 111           172.00                   34.20        26.50               8.00
# 112             None                   20.39        23.51               7.34
# 113            95.00                   23.30        33.00              13.00
# 114             None                   18.08        19.65               6.62
# 115             8.00                    0.00         4.50               4.00
# 116           112.00                   39.70        14.00               6.00
# 117             None                   17.42        24.82               7.33
# 118            18.00                    1.00         3.50               3.00
# 119            41.00                    1.10        24.50               9.00
# 120            14.00                    0.70         2.00               3.00
# 121           136.00                   27.40         9.00               7.00
# 122           165.00                   13.30         7.00               6.00
# 123           173.00                    6.80         8.50               4.00
# 124             4.00                    0.20         3.50               5.00
# 125            16.00                   17.20         3.80               2.00
# 126           168.00                    8.70        19.50               9.00
# 127           159.00                   45.40        32.00              11.00
# 128             None                    6.25        11.27               5.56
# 129            79.00                    1.50         4.00               3.00
# 130             6.00                    1.00         4.20               6.00
# 131            20.00                    0.70        13.00               3.00
# 132           111.00                   15.20        12.00               5.00
# 133            50.00                    1.20        12.00               8.00
# 134             None                    4.05        13.28               5.09
# 135             None                   37.55        23.40               6.84
# 136             5.00                   14.60         8.00               3.00
# 137             None                   32.08        20.44               6.67
# 138           140.00                   76.60        27.00               9.00
# 139            85.00                   34.00         8.50               7.00
# 140            23.00                    0.30         1.50               2.00
# 141            66.00                    1.10         5.50               3.00
# 142           169.00                   13.30        10.00               7.00
# 143           124.00                    4.20        16.60              11.00
# 144             None                   51.72        24.21               7.11
# 150      8108724470.06
# 151       667550799.45
# 152    772092381051.92
# 153      4525879635.59
# 154       210634634.39
# 155       297509670.51
# 156    208310781648.72
# 157        51406548.55
# 158       508987273.56
# 159      5896486375.84
# 160       848181874.79
# 161     16513900451.39
# 162      9642963520.52
# 163     14073123560.53
# 164      3130500123.96
# 165        88636680.44
# 166    572787504238.04
# 167       259394006.39
# 168    212598413542.80
# 169       500091785.58
# 170       646808523.62
# 171     46207208127.91
# 172       178281662.74
# 173         6532570.63
# 174        18248267.02
# 175     20600747773.60
# 176     13234922852.84
# 177       130576026.30
# 178     99716560908.64
# 179       707058387.41
# 180     55799904983.05
# 181       391820762.91
# 182       453970228.86
# 183      7629383513.94
# 184       487698288.01
# 185       733304062.67
# 186       146815277.30
# 187       342421156.56
# 188    106380745399.10
# 189      1123506762.49
# 190     29234584559.39
# 191      8303434266.96
# 192     20568521114.65
# 193      5180535391.19
# 194       842140020.61
# 195       538484538.49
# 196      4492145463.14
# 197    302334353380.37
# 198      4269431456.16
# 199       708185073.79
# 200       206293116.56
# 201     54781412067.20
# 202       158726754.77
# 203     20294819984.58
# 204      2791409693.43
# 205       748672175.24
# 206      1393950643.90
# 207       377095451.85
# 208    183894719356.91
# 209     11884654144.06
# 210      1141512962.65
# 211     13463062258.79
# 212    287312191858.06
# 213     16861896999.17
# 214     42465061417.72
# 215  17563105454226.33
# 216      1592221747.14
# 217     21468642595.66
# 218               0.00
# 219    151880128285.03
# 220      1609937274.23

# %% [markdown]
# ### Step 4: Run Pipelines to Model the Data
# #### 4.1 Create the data model
# Build the data pipelines to create the data model.

# %%
# Here we are going to write the country dimension to an output csv file
wdicountryDimFinal \
    .coalesce(1) \
    .write.csv('/home/jovyan/work/data/CountryDim', mode='overwrite', header='true')

# %%
#Write the yearly totals to a CSV File
yrPivotDF \
    .select(col('year')
            , col('population').cast(DecimalType(38, 2))
            , col('population_age_0_to_14').cast(DecimalType(38, 2))
            , col('population_age_15_64').cast(DecimalType(38, 2))
            , col('population_age_65_and_above').cast(DecimalType(38, 2))
            , col('broadband_subscriptions').cast(DecimalType(38, 2))
            , col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('/home/jovyan/work/data/YearlyStats', mode='overwrite', header='true')

# %%
#Write the regional-yearly totals to a CSV File
countryPivot.filter('country_iso_code is not null') \
    .orderBy('country_iso_code','country_name', 'year') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population') \
    .select(col('country_iso_code')
            , col('country_name')
            , col('year')
            , col('population').cast(DecimalType(38, 2))
            , col('population_age_0_to_14').cast(DecimalType(38, 2))
            , col('population_age_15_64').cast(DecimalType(38, 2))
            , col('population_age_65_and_above').cast(DecimalType(38, 2))
            , col('broadband_subscriptions').cast(DecimalType(38, 2))
            , col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('/home/jovyan/work/data/CountryStats', mode='overwrite', header='true')

# %%
countryBusinessStrtupPivot \
    .select("Country ISO Code", "Country Name", "GDP", "GDP Per Capita", "GNI", \
            "Startup Cost", "Startup Cost Pct of GNI", "Startup Time", "Startup Procedures", \
            "Business Regulation", "Ease of business") \
    .coalesce(1) \
    .write.csv('/home/jovyan/work/data/BusinessStartupData', mode='overwrite', header='true')

# %%
#Write the regional-yearly totals to a CSV File
regionalPivot.filter('region is not null') \
    .orderBy('region','year') \
    .withColumnRenamed('IT.CEL.SETS', 'cellular_subscriptions') \
    .withColumnRenamed('IT.NET.BBND', 'broadband_subscriptions') \
    .withColumnRenamed('SP.POP.0014.TO', 'population_age_0_to_14') \
    .withColumnRenamed('SP.POP.1564.TO', 'population_age_15_64') \
    .withColumnRenamed('SP.POP.65UP.TO', 'population_age_65_and_above') \
    .withColumnRenamed('SP.POP.TOTL', 'population') \
    .select(col('region')
            , col('year')
            , col('population').cast(DecimalType(38, 2))
            , col('population_age_0_to_14').cast(DecimalType(38, 2))
            , col('population_age_15_64').cast(DecimalType(38, 2))
            , col('population_age_65_and_above').cast(DecimalType(38, 2))
            , col('broadband_subscriptions').cast(DecimalType(38, 2))
            , col('cellular_subscriptions').cast(DecimalType(38, 2))) \
    .coalesce(1) \
    .write.csv('/home/jovyan/work/data/RegionalStats', mode='overwrite', header='true')

# %% [markdown]
# #### 4.2 Data Quality Checks
# Explain the data quality checks you'll perform to ensure the pipeline ran as expected. These could include:
#  * Integrity constraints on the relational database (e.g., unique key, data type, etc.)
#  * Unit tests for the scripts to ensure they are doing the right thing
#  * Source/Count checks to ensure completeness
#
# Run Quality Checks

# %% [markdown]
# ##### Do all countries have 2 character country_iso_codes ?

# %%
countryCodeLengthQuery = """
select 
    length(country_iso_code) as column_length
    , count(1) as cnt
from 
    wdicountry
group by 
    length(country_iso_code)
having 
    count(1) > 1
"""

showDF(spark.sql(countryCodeLengthQuery))
# Out:
#    column_length  cnt
# 0              2  262

# %% [markdown]
# ##### Do we have duplicate records for any of the key columns ?

# %%
targetcnt = wdicountryDim.count()
sourcecnt = wdicountry.count()

if targetcnt != sourcecnt :
    raise ValueError('Count is not matching with source')
else:
    print('Data quality check is passed')
# Out:
# Data quality check is passed

# %%
showDF(wdicountryDim.groupBy("country_iso_code").agg(count("*").alias("cnt")).filter("cnt > 1"))

showDF(wdicountryDim.groupBy("wb_country_code").agg(count("*").alias("cnt")).filter("cnt > 1"))

showDF(wdicountryDim.groupBy("country_name").agg(count("*").alias("cnt")).filter("cnt > 1"))
# Out:
# Empty DataFrame
# Columns: [country_iso_code, cnt]
# Index: []
# Empty DataFrame
# Columns: [wb_country_code, cnt]
# Index: []
# Empty DataFrame
# Columns: [country_name, cnt]
# Index: []

# %% [markdown]
# ##### Any country with Country_iso_code is null?

# %%
wdicountryDimFinal = wdicountryDim.filter("country_iso_code is not null")

showDF(wdicountryDimFinal)
# Out:
#    country_iso_code wb_country_code          country_name  \
# 0                AW             ABW                 Aruba
# 1                AF             AFG           Afghanistan
# 2                AO             AGO                Angola
# 3                AL             ALB               Albania
# 4                AD             AND               Andorra
# 5                1A             ARB            Arab World
# 6                AE             ARE  United Arab Emirates
# 7                AR             ARG             Argentina
# 8                AM             ARM               Armenia
# 9                AS             ASM        American Samoa
# 10               AG             ATG   Antigua and Barbuda
# 11               AU             AUS             Australia
# 12               AT             AUT               Austria
# 13               AZ             AZE            Azerbaijan
# 14               BI             BDI               Burundi
# 15               BE             BEL               Belgium
# 16               BJ             BEN                 Benin
# 17               BF             BFA          Burkina Faso
# 18               BD             BGD            Bangladesh
# 19               BG             BGR              Bulgaria
#
#                   country_long_name                      region  \
# 0                             Aruba   Latin America & Caribbean
# 1      Islamic State of Afghanistan                  South Asia
# 2       People's Republic of Angola          Sub-Saharan Africa
# 3               Republic of Albania       Europe & Central Asia
# 4           Principality of Andorra       Europe & Central Asia
# 5                        Arab World                        None
# 6              United Arab Emirates  Middle East & North Africa
# 7                Argentine Republic                        None
# 8               Republic of Armenia       Europe & Central Asia
# 9                    American Samoa         East Asia & Pacific
# 10              Antigua and Barbuda   Latin America & Caribbean
# 11        Commonwealth of Australia         East Asia & Pacific
# 12              Republic of Austria       Europe & Central Asia
# 13           Republic of Azerbaijan       Europe & Central Asia
# 14              Republic of Burundi          Sub-Saharan Africa
# 15               Kingdom of Belgium       Europe & Central Asia
# 16                Republic of Benin          Sub-Saharan Africa
# 17                     Burkina Faso          Sub-Saharan Africa
# 18  People's Republic of Bangladesh                  South Asia
# 19             Republic of Bulgaria       Europe & Central Asia
#
#            income_group
# 0           High income
# 1            Low income
# 2   Lower middle income
# 3   Upper middle income
# 4           High income
# 5                  None
# 6           High income
# 7                  None
# 8   Lower middle income
# 9   Upper middle income
# 10          High income
# 11          High income
# 12          High income
# 13  Upper middle income
# 14           Low income
# 15          High income
# 16           Low income
# 17           Low income
# 18  Lower middle income
# 19  Upper middle income

# %%
wdicountryDimFinal.count()
# Out:
# 262

# %%
# You can iterate over a dataframe that is already computed by caching it onces and using it repeatedly
yrPivotDF.cache()

#Forces the data to be cached
yrPivotDF.count()
# Out:
# 60

# %% [markdown]
# ##### Do we have invalid records for any of the key population_age column ?

# %%
yrPivotDF.filter('population_age_0_to_14 < 0').count()
# Out:
# 0

# %%
yrPivotDF.filter('population_age_15_64 < 0').count()
# Out:
# 0

# %%
yrPivotDF.filter('population_age_0_to_14 < 0').count()
# Out:
# 0

# %%
yrPivotDF.filter('population_age_65_and_above < 0').count()
# Out:
# 0

# %%
yrPivotDF.filter('population < 0').count()
# Out:
# 0

# %%
yrPivotDF.filter('cellular_subscriptions < 0').count()
# Out:
# 0

# %%
yrPivotDF.filter('broadband_subscriptions < 0').count()
# Out:
# 0

# %%
yrPivotDF.filter('population_age_0_to_14 > population').count()
# Out:
# 0

# %%
yrPivotDF.filter('population_age_15_64 > population').count()
# Out:
# 0

# %%
yrPivotDF.filter('population_age_65_and_above > population').count()
# Out:
# 0

# %% [markdown]
# #### 4.3 Data dictionary
# Create a data dictionary for your data model. For each field, provide a brief description of what the data is and where it came from. You can include the data dictionary in the notebook or in a separate file.

# %% [markdown]
# ### The data is organized in the following five tables.
#
# ##### countryDim
#
# #### This table contains details about all the countries information such as ISO country code, World Bank country code and income group that countries falls into
#
# ##### columns:
# - country_iso_code : The ISO country codes are internationally recognized codes that designate every country and it is like an                      acronym, that stands for a country or a state.
# - wb_country_code  : World Bank specific country code
# - name	           : Name of the country
# - long_name	       : Long Name of the country
# - region	       : Region in which the country falls in in
# - income_group	   : Income group of the country's people
#
# ##### countryStats
#
# #### This table contains details about the total population count, age wise population count, number of broadband connections and cellular subscriptions by country
#
# ##### columns:
# - country_iso_code           : The ISO country codes are internationally recognized codes that designate every country and itis                                like an acronym, that stands for a country or a state.
# - country_name               : Name of the country
# - year                       : Year for which the statistics belongs to
# - population                 : Total population in the country
# - population_age_0_to_14     : Population of the people age from 0 to 14
# - population_age_15_64       : Population of the people age from 15 to 64
# - population_age_65_and_above: Population of the people age above 65
# - broadband_subscriptions    : Total number of broadband subscriptions in the country
# - cellular_subscriptions     : Total number of cellular subscriptions
#
# ##### RegionalStats
#
# #### This table contains same details as CountryStats but at the regional wise granularity instead of country wise
#
# ##### columns:
# - region                     : Name of the region under which the countries falls into
# - year                       : Year for which the statistics belongs to
# - population                 : Total population in the country
# - population_age_0_to_14     : Population of the people age from 0 to 14
# - population_age_15_64       : Population of the people age from 15 to 64
# - population_age_65_and_above: Population of the people age above 65
# - broadband_subscriptions    : Total number of broadband subscriptions in the country
# - cellular_subscriptions     : Total number of cellular subscriptions
#
# ##### YearlyStats
#
# #### This table contains same details as CountryStats but at the year wise granularity instead of country wise
#
# - year                       : Year for which the statistics belongs to
# - population                 : Total population in the country
# - population_age_0_to_14     : Population of the people age from 0 to 14
# - population_age_15_64       : Population of the people age from 15 to 64
# - population_age_65_and_above: Population of the people age above 65
# - broadband_subscriptions    : Total number of broadband subscriptions in the country
# - cellular_subscriptions     : Total number of cellular subscriptions
#
# ##### BusinessStartupData
#
# #### This table contains details about the start up statistics of the countries along with GDP and GDP per capita details
#
# - Country ISO Code         : The ISO country codes are internationally recognized codes that designate every country and itis                                like an acronym, that stands for a country or a state.
# - Country Name             : Name of the country
# - GDP                      : Gross Domestic Product. GDP is the final value of the goods and services produced within the                                    geographic boundaries of a country during a specified period of time, normally a year.
# - GDP Per Capita           : GDP per capita, is a measure of a country's economic output that accounts for its number of                                    people.
# - GNI                      : Gross national income (GNI), the sum of a country's gross domestic product (GDP) plus net income                                (positive or negative) from abroad.
# - Startup Cost             : Cost of starting a new business in the country
# - Startup Cost Pct of GNI  : Startup cost percentage compared to GNI
# - Startup Time             : Time required for starting up a Business
# - Startup Procedures       : Indicator denoting Procedures involved in Starting up a Business
# - Business Regulation      : Indicator denoting Business regulation for starting up a Business
# - Ease of business         : Indicator denoting ease of doing Business in the country

# %% [markdown]
# #### Step 5: Complete Project Write Up
# * Clearly state the rationale for the choice of tools and technologies for the project.
# * Propose how often the data should be updated and why.
# * Write a description of how you would approach the problem differently under the following scenarios:
#  * The data was increased by 100x.
#  ##### The whole ETL pipeline can be configured to load the data in Amazon Redshift and built on Amazon EMR cluster
#  - Redshift: Analytical database, optimized for aggregation, also good performance for read-heavy workloads
#  - Increase EMR cluster size to handle bigger volume of data
#  * The data populates a dashboard that must be updated on a daily basis by 7am every day.
#  ##### The ETL pipeline can be set up as Airflow DAGs and be triggered based on the SLA time
#  - DAG is scheduled to run every 10 minutes and can be configured to run every morning at 7 AM if required.
#  - Data quality operators are used at appropriate position. In case of DAG failures email triggers can be configured to let the    team know about pipeline failures.
#  * The database needed to be accessed by 100+ people.
#  - We can set the concurrency limit for your Amazon Redshift cluster. While the concurrency limit is 50 parallel queries for a    single period of time, this is on a per cluster basis, meaning you can launch as many clusters as fit for you business.
#  ##### Spark for ETL
#  - Spark helps data scientists by supporting the entire data science workflow, from data access and integration to machine        learning and visualization using the language of choice—which is typically Python. It also provides a growing library of        machine-learning algorithms through its machine-learning library (MLlib).
#  ##### Pandas
#  - Pandas is the most popular python library that is used for data analysis. It provides highly optimized performance with        back-end source code is purely written in C or Python.
#    - We can analyze data in pandas with:
#      - Series
#      - DataFrames
